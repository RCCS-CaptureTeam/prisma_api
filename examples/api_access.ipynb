# %% [markdown]
# # PrISMa_API

# %% [markdown]
# ### Load Library

# %%
import prisma_api

# %% [markdown]
# ### Initialise API class

# %%
api = prisma_api.init()
# from prisma_api.config import update_dev_mode
# update_dev_mode(False)
# api = prisma_api.init()

# %% [markdown]
# ### Gather MOF data from API

# %%
api.get_mofs()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Gather Carbon Isotherm data from API (using dynamic filtering)

# %%
api.get_carbon_isotherms({'molecule': 'CO2', 'good_structure': False})
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # TESTS
#
# ### adsorption_singlepoint
#
# Load sample data for upload

# %%
import pandas as pd

# %%
df = pd.read_csv('../../AutoPrism/results/adsorption_singlepoint.csv')
api.update_adsorption_singlepoint(df)
# Out:
# {'created_count': 0,
#  'updated_count': 995,
#  'error_count': 0,
#  'created_records': [],
#  'updated_records': [{'id': 1211,
#    'structure': '05000N2_ddec.cif',
#    'md5': '38fa1a4a57d75602d1f962e5be326796',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 1212,
#    'structure': '05000N2_ddec.cif',
#    'md5': '38fa1a4a57d75602d1f962e5be326796',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.001683,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 8.35155e-05,
#    'avg_number_of_molecules': 0.0013},
#   {'id': 1213,
#    'structure': '05000N2_ddec.cif',
#    'md5': '38fa1a4a57d75602d1f962e5be326796',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.997933,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 1214,
#    'structure': '05000N2_ddec.cif',
#    'md5': '38fa1a4a57d75602d1f962e5be326796',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 1215,
#    'structure': '05000N2_ddec.cif',
#    'md5': '38fa1a4a57d75602d1f962e5be326796',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.003366,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0001927281,
#    'avg_number_of_molecules': 0.003},
#   {'id': 1216,
#    'structure': '05000N2_ddec.cif',
#    'md5': '38fa1a4a57d75602d1f962e5be326796',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.99625,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 1217,
#    'structure': '05000N2_ddec.cif',
#    'md5': '38fa1a4a57d75602d1f962e5be326796',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000381,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 1218,
#    'structure': '05000N2_ddec.cif',
#    'md5': '38fa1a4a57d75602d1f962e5be326796',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.010439,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0006038815,
#    'avg_number_of_molecules': 0.0094},
#   {'id': 1219,
#    'structure': '05000N2_ddec.cif',
#    'md5': '38fa1a4a57d75602d1f962e5be326796',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.98918,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 1220,
#    'structure': '05000N2_ddec.cif',
#    'md5': '38fa1a4a57d75602d1f962e5be326796',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000385,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 1221,
#    'structure': '05000N2_ddec.cif',
#    'md5': '38fa1a4a57d75602d1f962e5be326796',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2',
#    'mol_fraction': 0.999615,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 1222,
#    'structure': '05001N2_ddec.cif',
#    'md5': 'd09dd23c55c78b140591d8566883ebbc',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0006269252,
#    'avg_number_of_molecules': 0.01865},
#   {'id': 1223,
#    'structure': '05001N2_ddec.cif',
#    'md5': 'd09dd23c55c78b140591d8566883ebbc',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.001683,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.000635329,
#    'avg_number_of_molecules': 0.0189},
#   {'id': 1224,
#    'structure': '05001N2_ddec.cif',
#    'md5': 'd09dd23c55c78b140591d8566883ebbc',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.997933,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.2681257,
#    'avg_number_of_molecules': 7.9763},
#   {'id': 1225,
#    'structure': '05001N2_ddec.cif',
#    'md5': 'd09dd23c55c78b140591d8566883ebbc',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.000606756,
#    'avg_number_of_molecules': 0.01805},
#   {'id': 1226,
#    'structure': '05001N2_ddec.cif',
#    'md5': 'd09dd23c55c78b140591d8566883ebbc',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.003366,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.001198385,
#    'avg_number_of_molecules': 0.03565},
#   {'id': 1227,
#    'structure': '05001N2_ddec.cif',
#    'md5': 'd09dd23c55c78b140591d8566883ebbc',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.99625,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.2646246,
#    'avg_number_of_molecules': 7.87215},
#   {'id': 1228,
#    'structure': '05001N2_ddec.cif',
#    'md5': 'd09dd23c55c78b140591d8566883ebbc',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000381,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0005479293,
#    'avg_number_of_molecules': 0.0163},
#   {'id': 1229,
#    'structure': '05001N2_ddec.cif',
#    'md5': 'd09dd23c55c78b140591d8566883ebbc',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.010439,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.003623729,
#    'avg_number_of_molecules': 0.1078},
#   {'id': 1230,
#    'structure': '05001N2_ddec.cif',
#    'md5': 'd09dd23c55c78b140591d8566883ebbc',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.98918,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.2614446,
#    'avg_number_of_molecules': 7.77755},
#   {'id': 1231,
#    'structure': '05001N2_ddec.cif',
#    'md5': 'd09dd23c55c78b140591d8566883ebbc',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000385,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0005697792,
#    'avg_number_of_molecules': 0.01695},
#   {'id': 1232,
#    'structure': '05001N2_ddec.cif',
#    'md5': 'd09dd23c55c78b140591d8566883ebbc',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2',
#    'mol_fraction': 0.999615,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.2651742,
#    'avg_number_of_molecules': 7.8885},
#   {'id': 1233,
#    'structure': '07000N2_ddec.cif',
#    'md5': '17ca1f693001d5f4b62e9215cd6379eb',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0006153226,
#    'avg_number_of_molecules': 0.0057},
#   {'id': 1234,
#    'structure': '07000N2_ddec.cif',
#    'md5': '17ca1f693001d5f4b62e9215cd6379eb',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.001683,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0006962861,
#    'avg_number_of_molecules': 0.00645},
#   {'id': 1235,
#    'structure': '07000N2_ddec.cif',
#    'md5': '17ca1f693001d5f4b62e9215cd6379eb',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.997933,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.2838041,
#    'avg_number_of_molecules': 2.629},
#   {'id': 1236,
#    'structure': '07000N2_ddec.cif',
#    'md5': '17ca1f693001d5f4b62e9215cd6379eb',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0006369129,
#    'avg_number_of_molecules': 0.0059},
#   {'id': 1237,
#    'structure': '07000N2_ddec.cif',
#    'md5': '17ca1f693001d5f4b62e9215cd6379eb',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.003366,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.00124144,
#    'avg_number_of_molecules': 0.0115},
#   {'id': 1238,
#    'structure': '07000N2_ddec.cif',
#    'md5': '17ca1f693001d5f4b62e9215cd6379eb',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.99625,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.2851858,
#    'avg_number_of_molecules': 2.6418},
#   {'id': 1239,
#    'structure': '07000N2_ddec.cif',
#    'md5': '17ca1f693001d5f4b62e9215cd6379eb',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000381,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0005289615,
#    'avg_number_of_molecules': 0.0049},
#   {'id': 1240,
#    'structure': '07000N2_ddec.cif',
#    'md5': '17ca1f693001d5f4b62e9215cd6379eb',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.010439,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.004582534,
#    'avg_number_of_molecules': 0.04245},
#   {'id': 1241,
#    'structure': '07000N2_ddec.cif',
#    'md5': '17ca1f693001d5f4b62e9215cd6379eb',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.98918,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.2795346,
#    'avg_number_of_molecules': 2.58945},
#   {'id': 1242,
#    'structure': '07000N2_ddec.cif',
#    'md5': '17ca1f693001d5f4b62e9215cd6379eb',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000385,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0005829372,
#    'avg_number_of_molecules': 0.0054},
#   {'id': 1243,
#    'structure': '07000N2_ddec.cif',
#    'md5': '17ca1f693001d5f4b62e9215cd6379eb',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2',
#    'mol_fraction': 0.999615,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.282989,
#    'avg_number_of_molecules': 2.62145},
#   {'id': 1244,
#    'structure': '07001N2_ddec.cif',
#    'md5': '07efdb27d3ccf4e78e03da044906f917',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.003939021,
#    'avg_number_of_molecules': 0.0805},
#   {'id': 1245,
#    'structure': '07001N2_ddec.cif',
#    'md5': '07efdb27d3ccf4e78e03da044906f917',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.001683,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.001032464,
#    'avg_number_of_molecules': 0.0211},
#   {'id': 1246,
#    'structure': '07001N2_ddec.cif',
#    'md5': '07efdb27d3ccf4e78e03da044906f917',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.997933,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.6288512,
#    'avg_number_of_molecules': 12.85155},
#   {'id': 1247,
#    'structure': '07001N2_ddec.cif',
#    'md5': '07efdb27d3ccf4e78e03da044906f917',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.00397572,
#    'avg_number_of_molecules': 0.08125},
#   {'id': 1248,
#    'structure': '07001N2_ddec.cif',
#    'md5': '07efdb27d3ccf4e78e03da044906f917',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.003366,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.002111413,
#    'avg_number_of_molecules': 0.04315},
#   {'id': 1249,
#    'structure': '07001N2_ddec.cif',
#    'md5': '07efdb27d3ccf4e78e03da044906f917',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.99625,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.6349285,
#    'avg_number_of_molecules': 12.97575},
#   {'id': 1250,
#    'structure': '07001N2_ddec.cif',
#    'md5': '07efdb27d3ccf4e78e03da044906f917',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000381,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.003934127,
#    'avg_number_of_molecules': 0.0804},
#   {'id': 1251,
#    'structure': '07001N2_ddec.cif',
#    'md5': '07efdb27d3ccf4e78e03da044906f917',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.010439,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.006011288,
#    'avg_number_of_molecules': 0.12285},
#   {'id': 1252,
#    'structure': '07001N2_ddec.cif',
#    'md5': '07efdb27d3ccf4e78e03da044906f917',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.98918,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.6238283,
#    'avg_number_of_molecules': 12.7489},
#   {'id': 1253,
#    'structure': '07001N2_ddec.cif',
#    'md5': '07efdb27d3ccf4e78e03da044906f917',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000385,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.003872963,
#    'avg_number_of_molecules': 0.07915},
#   {'id': 1254,
#    'structure': '07001N2_ddec.cif',
#    'md5': '07efdb27d3ccf4e78e03da044906f917',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2',
#    'mol_fraction': 0.999615,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.6348087,
#    'avg_number_of_molecules': 12.9733},
#   {'id': 1255,
#    'structure': '08000N3_ddec.cif',
#    'md5': '1da8a7bc1aa56632455c6c2b643c2d7c',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.00243062,
#    'avg_number_of_molecules': 0.02085},
#   {'id': 1256,
#    'structure': '08000N3_ddec.cif',
#    'md5': '1da8a7bc1aa56632455c6c2b643c2d7c',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.001683,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0009675849,
#    'avg_number_of_molecules': 0.0083},
#   {'id': 1257,
#    'structure': '08000N3_ddec.cif',
#    'md5': '1da8a7bc1aa56632455c6c2b643c2d7c',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.997933,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.694114,
#    'avg_number_of_molecules': 5.95415},
#   {'id': 1258,
#    'structure': '08000N3_ddec.cif',
#    'md5': '1da8a7bc1aa56632455c6c2b643c2d7c',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.002302386,
#    'avg_number_of_molecules': 0.01975},
#   {'id': 1259,
#    'structure': '08000N3_ddec.cif',
#    'md5': '1da8a7bc1aa56632455c6c2b643c2d7c',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.003366,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.001923512,
#    'avg_number_of_molecules': 0.0165},
#   {'id': 1260,
#    'structure': '08000N3_ddec.cif',
#    'md5': '1da8a7bc1aa56632455c6c2b643c2d7c',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.99625,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.6936418,
#    'avg_number_of_molecules': 5.9501},
#   {'id': 1261,
#    'structure': '08000N3_ddec.cif',
#    'md5': '1da8a7bc1aa56632455c6c2b643c2d7c',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000381,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.002115863,
#    'avg_number_of_molecules': 0.01815},
#   {'id': 1262,
#    'structure': '08000N3_ddec.cif',
#    'md5': '1da8a7bc1aa56632455c6c2b643c2d7c',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.010439,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.005793852,
#    'avg_number_of_molecules': 0.0497},
#   {'id': 1263,
#    'structure': '08000N3_ddec.cif',
#    'md5': '1da8a7bc1aa56632455c6c2b643c2d7c',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.98918,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.690401,
#    'avg_number_of_molecules': 5.9223},
#   {'id': 1264,
#    'structure': '08000N3_ddec.cif',
#    'md5': '1da8a7bc1aa56632455c6c2b643c2d7c',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000385,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.002448106,
#    'avg_number_of_molecules': 0.021},
#   {'id': 1265,
#    'structure': '08000N3_ddec.cif',
#    'md5': '1da8a7bc1aa56632455c6c2b643c2d7c',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2',
#    'mol_fraction': 0.999615,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.6952506,
#    'avg_number_of_molecules': 5.9639},
#   {'id': 1266,
#    'structure': '15070N2_ddec.cif',
#    'md5': 'c5c5b4ebd33465b24ded58a5d4f49b24',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0005545606,
#    'avg_number_of_molecules': 0.00485},
#   {'id': 1267,
#    'structure': '15070N2_ddec.cif',
#    'md5': 'c5c5b4ebd33465b24ded58a5d4f49b24',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.001683,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.004539393,
#    'avg_number_of_molecules': 0.0397},
#   {'id': 1268,
#    'structure': '15070N2_ddec.cif',
#    'md5': 'c5c5b4ebd33465b24ded58a5d4f49b24',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.997933,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.2747819,
#    'avg_number_of_molecules': 2.40315},
#   {'id': 1269,
#    'structure': '15070N2_ddec.cif',
#    'md5': 'c5c5b4ebd33465b24ded58a5d4f49b24',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0006517517,
#    'avg_number_of_molecules': 0.0057},
#   {'id': 1270,
#    'structure': '15070N2_ddec.cif',
#    'md5': 'c5c5b4ebd33465b24ded58a5d4f49b24',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.003366,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.01044518,
#    'avg_number_of_molecules': 0.09135},
#   {'id': 1271,
#    'structure': '15070N2_ddec.cif',
#    'md5': 'c5c5b4ebd33465b24ded58a5d4f49b24',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.99625,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.2778349,
#    'avg_number_of_molecules': 2.42985},
#   {'id': 1272,
#    'structure': '15070N2_ddec.cif',
#    'md5': 'c5c5b4ebd33465b24ded58a5d4f49b24',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000381,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0005431264,
#    'avg_number_of_molecules': 0.00475},
#   {'id': 1273,
#    'structure': '15070N2_ddec.cif',
#    'md5': 'c5c5b4ebd33465b24ded58a5d4f49b24',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.010439,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.03323933,
#    'avg_number_of_molecules': 0.2907},
#   {'id': 1274,
#    'structure': '15070N2_ddec.cif',
#    'md5': 'c5c5b4ebd33465b24ded58a5d4f49b24',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.98918,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.270637,
#    'avg_number_of_molecules': 2.3669},
#   {'id': 1275,
#    'structure': '15070N2_ddec.cif',
#    'md5': 'c5c5b4ebd33465b24ded58a5d4f49b24',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000385,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0005374093,
#    'avg_number_of_molecules': 0.0047},
#   {'id': 1276,
#    'structure': '15070N2_ddec.cif',
#    'md5': 'c5c5b4ebd33465b24ded58a5d4f49b24',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2',
#    'mol_fraction': 0.999615,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.2725523,
#    'avg_number_of_molecules': 2.38365},
#   {'id': 1277,
#    'structure': '16057N2_ddec.cif',
#    'md5': '6202432f901e6b6d68c4dd3bc2ce866c',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0007243459,
#    'avg_number_of_molecules': 0.01255},
#   {'id': 1278,
#    'structure': '16057N2_ddec.cif',
#    'md5': '6202432f901e6b6d68c4dd3bc2ce866c',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.001683,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.001780563,
#    'avg_number_of_molecules': 0.03085},
#   {'id': 1279,
#    'structure': '16057N2_ddec.cif',
#    'md5': '6202432f901e6b6d68c4dd3bc2ce866c',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.997933,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.2758805,
#    'avg_number_of_molecules': 4.7799},
#   {'id': 1280,
# ...
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2',
#    'mol_fraction': 0.999615,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.8217768,
#    'avg_number_of_molecules': 9.4231},
#   {'id': 2184,
#    'structure': 'qmof-cb9ea13.cif',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.007392899,
#    'avg_number_of_molecules': 0.12215},
#   {'id': 2185,
#    'structure': 'qmof-cb9ea13.cif',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.001683,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.1014912,
#    'avg_number_of_molecules': 1.6769},
#   {'id': 2186,
#    'structure': 'qmof-cb9ea13.cif',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.997933,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.7466495,
#    'avg_number_of_molecules': 12.3366},
#   {'id': 2187,
#    'structure': 'qmof-cb9ea13.cif',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.006899636,
#    'avg_number_of_molecules': 0.114},
#   {'id': 2188,
#    'structure': 'qmof-cb9ea13.cif',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.003366,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.211834,
#    'avg_number_of_molecules': 3.50005},
#   {'id': 2189,
#    'structure': 'qmof-cb9ea13.cif',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.99625,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.7268555,
#    'avg_number_of_molecules': 12.00955},
#   {'id': 2190,
#    'structure': 'qmof-cb9ea13.cif',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000381,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.007504867,
#    'avg_number_of_molecules': 0.124},
#   {'id': 2191,
#    'structure': 'qmof-cb9ea13.cif',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.010439,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.5922218,
#    'avg_number_of_molecules': 9.78505},
#   {'id': 2192,
#    'structure': 'qmof-cb9ea13.cif',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.98918,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.7006731,
#    'avg_number_of_molecules': 11.57695},
#   {'id': 2193,
#    'structure': 'qmof-cb9ea13.cif',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000385,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.007616835,
#    'avg_number_of_molecules': 0.12585},
#   {'id': 2194,
#    'structure': 'qmof-cb9ea13.cif',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2',
#    'mol_fraction': 0.999615,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.7488102,
#    'avg_number_of_molecules': 12.3723},
#   {'id': 2195,
#    'structure': 'str_m4_o1_o4_acs_sym.68.cif',
#    'md5': '1c9a5d68fac18068899ecdbb6a47507f',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 2196,
#    'structure': 'str_m4_o1_o4_acs_sym.68.cif',
#    'md5': '1c9a5d68fac18068899ecdbb6a47507f',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.001683,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 2197,
#    'structure': 'str_m4_o1_o4_acs_sym.68.cif',
#    'md5': '1c9a5d68fac18068899ecdbb6a47507f',
#    'mixture_id': 'mineralization_RH10',
#    'mixture': 'mineralization_RH10',
#    'config_hash': '6e18fe4ed66d8e90c2e2a4efeec2b737d321cc98',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.997933,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 2198,
#    'structure': 'str_m4_o1_o4_acs_sym.68.cif',
#    'md5': '1c9a5d68fac18068899ecdbb6a47507f',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000384,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 2199,
#    'structure': 'str_m4_o1_o4_acs_sym.68.cif',
#    'md5': '1c9a5d68fac18068899ecdbb6a47507f',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.003366,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 2200,
#    'structure': 'str_m4_o1_o4_acs_sym.68.cif',
#    'md5': '1c9a5d68fac18068899ecdbb6a47507f',
#    'mixture_id': 'mineralization_RH20',
#    'mixture': 'mineralization_RH20',
#    'config_hash': '2c91aabca41eca24c02cb2a7509fe106d79763dc',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.99625,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 2201,
#    'structure': 'str_m4_o1_o4_acs_sym.68.cif',
#    'md5': '1c9a5d68fac18068899ecdbb6a47507f',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000381,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 2202,
#    'structure': 'str_m4_o1_o4_acs_sym.68.cif',
#    'md5': '1c9a5d68fac18068899ecdbb6a47507f',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'H2O',
#    'component_label': 'H2O',
#    'mol_fraction': 0.010439,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 2203,
#    'structure': 'str_m4_o1_o4_acs_sym.68.cif',
#    'md5': '1c9a5d68fac18068899ecdbb6a47507f',
#    'mixture_id': 'mineralization_wet',
#    'mixture': 'mineralization_RH60',
#    'config_hash': 'a1213b28f8e092a146dd9232a5673b34ae5803ef',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2*',
#    'mol_fraction': 0.98918,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 2204,
#    'structure': 'str_m4_o1_o4_acs_sym.68.cif',
#    'md5': '1c9a5d68fac18068899ecdbb6a47507f',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'CO2',
#    'component_label': 'CO2',
#    'mol_fraction': 0.000385,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0},
#   {'id': 2205,
#    'structure': 'str_m4_o1_o4_acs_sym.68.cif',
#    'md5': '1c9a5d68fac18068899ecdbb6a47507f',
#    'mixture_id': 'mineralization_dry',
#    'mixture': 'mineralization_dry',
#    'config_hash': '87ebea8fd22a64ffef305106d14164469552372b',
#    'temperature_K': 288.15,
#    'pressure_bar': 1.01325,
#    'component': 'N2',
#    'component_label': 'N2',
#    'mol_fraction': 0.999615,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': True,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'absolute_loading_mol_kg': 0.0,
#    'avg_number_of_molecules': 0.0}]}

# %%
df = pd.read_csv('../../AutoPrism/results/heat_capacity_all_tidy.csv')
api.update_heat_capacity_all_tidy(df)
# Out:
# {'created_count': 0,
#  'updated_count': 297,
#  'error_count': 0,
#  'created_records': [],
#  'updated_records': [{'id': 274,
#    'structure': '05000N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9504490424,
#    'Cv_gravimetric_std': 0.0067526597,
#    'Cv_molar_mean': 8.806371,
#    'Cv_molar_std': 0.06256662},
#   {'id': 275,
#    'structure': '05000N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9877726606,
#    'Cv_gravimetric_std': 0.0165762333,
#    'Cv_molar_mean': 9.152191,
#    'Cv_molar_std': 0.15358692},
#   {'id': 276,
#    'structure': '05000N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.3508411517,
#    'Cv_gravimetric_std': 0.0073491172,
#    'Cv_molar_mean': 12.516195,
#    'Cv_molar_std': 0.06809314},
#   {'id': 277,
#    'structure': '05001N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9134831525,
#    'Cv_gravimetric_std': 0.0034719791,
#    'Cv_molar_mean': 8.84582,
#    'Cv_molar_std': 0.03362133},
#   {'id': 278,
#    'structure': '05001N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9460689268,
#    'Cv_gravimetric_std': 0.0051291879,
#    'Cv_molar_mean': 9.161367,
#    'Cv_molar_std': 0.049669106},
#   {'id': 279,
#    'structure': '05001N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.2989612504,
#    'Cv_gravimetric_std': 0.0028943488,
#    'Cv_molar_mean': 12.578642,
#    'Cv_molar_std': 0.02802775},
#   {'id': 280,
#    'structure': '07000N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.941810283,
#    'Cv_gravimetric_std': 0.0035872851,
#    'Cv_molar_mean': 8.655049,
#    'Cv_molar_std': 0.032966483},
#   {'id': 281,
#    'structure': '07000N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9790641003,
#    'Cv_gravimetric_std': 0.0060967956,
#    'Cv_molar_mean': 8.997405,
#    'Cv_molar_std': 0.056028366},
#   {'id': 282,
#    'structure': '07000N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.3438815609,
#    'Cv_gravimetric_std': 0.0022289087,
#    'Cv_molar_mean': 12.350005,
#    'Cv_molar_std': 0.020483037},
#   {'id': 283,
#    'structure': '07001N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.8908432138,
#    'Cv_gravimetric_std': 0.0033524744,
#    'Cv_molar_mean': 9.030556,
#    'Cv_molar_std': 0.033984214},
#   {'id': 284,
#    'structure': '07001N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9254381494,
#    'Cv_gravimetric_std': 0.0023763542,
#    'Cv_molar_mean': 9.381247,
#    'Cv_molar_std': 0.024089215},
#   {'id': 285,
#    'structure': '07001N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.2598740882,
#    'Cv_gravimetric_std': 0.0023055153,
#    'Cv_molar_mean': 12.771454,
#    'Cv_molar_std': 0.023371257},
#   {'id': 286,
#    'structure': '08000N3_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 1.086318928,
#    'Cv_gravimetric_std': 0.0096268824,
#    'Cv_molar_mean': 8.596348,
#    'Cv_molar_std': 0.07618025},
#   {'id': 287,
#    'structure': '08000N3_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 1.128669263,
#    'Cv_gravimetric_std': 0.0091362087,
#    'Cv_molar_mean': 8.9314785,
#    'Cv_molar_std': 0.07229739},
#   {'id': 288,
#    'structure': '08000N3_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.499937909,
#    'Cv_gravimetric_std': 0.0028839818,
#    'Cv_molar_mean': 11.869432,
#    'Cv_molar_std': 0.022821696},
#   {'id': 289,
#    'structure': '15070N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9977275515,
#    'Cv_gravimetric_std': 0.0057788157,
#    'Cv_molar_mean': 8.262909,
#    'Cv_molar_std': 0.047858667},
#   {'id': 290,
#    'structure': '15070N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 1.0417371801,
#    'Cv_gravimetric_std': 0.0072071819,
#    'Cv_molar_mean': 8.627384,
#    'Cv_molar_std': 0.059688047},
#   {'id': 291,
#    'structure': '15070N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.4321308577,
#    'Cv_gravimetric_std': 0.0048857969,
#    'Cv_molar_mean': 11.8605175,
#    'Cv_molar_std': 0.040462933},
#   {'id': 292,
#    'structure': '16057N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.8535140889,
#    'Cv_gravimetric_std': 0.0050184007,
#    'Cv_molar_mean': 9.577814,
#    'Cv_molar_std': 0.056314547},
#   {'id': 293,
#    'structure': '16057N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.8842819244,
#    'Cv_gravimetric_std': 0.0064068825,
#    'Cv_molar_mean': 9.923079,
#    'Cv_molar_std': 0.071895674},
#   {'id': 294,
#    'structure': '16057N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.1828500289,
#    'Cv_gravimetric_std': 0.0059609464,
#    'Cv_molar_mean': 13.273499,
#    'Cv_molar_std': 0.06689148},
#   {'id': 295,
#    'structure': '17150N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 1.06343769,
#    'Cv_gravimetric_std': 0.0023832607,
#    'Cv_molar_mean': 8.177443,
#    'Cv_molar_std': 0.018326288},
#   {'id': 296,
#    'structure': '17150N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 1.103414038,
#    'Cv_gravimetric_std': 0.0021784341,
#    'Cv_molar_mean': 8.484846,
#    'Cv_molar_std': 0.016751535},
#   {'id': 297,
#    'structure': '17150N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.5065739501,
#    'Cv_gravimetric_std': 0.0025756946,
#    'Cv_molar_mean': 11.584997,
#    'Cv_molar_std': 0.01980617},
#   {'id': 298,
#    'structure': '19020N3_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9738637821,
#    'Cv_gravimetric_std': 0.0107779478,
#    'Cv_molar_mean': 9.013264,
#    'Cv_molar_std': 0.09975162},
#   {'id': 298,
#    'structure': '19020N3_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9738637821,
#    'Cv_gravimetric_std': 0.0107779478,
#    'Cv_molar_mean': 9.013264,
#    'Cv_molar_std': 0.09975162},
#   {'id': 299,
#    'structure': '19020N3_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 1.0042580873,
#    'Cv_gravimetric_std': 0.0152906271,
#    'Cv_molar_mean': 9.294569,
#    'Cv_molar_std': 0.14151733},
#   {'id': 299,
#    'structure': '19020N3_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 1.0042580873,
#    'Cv_gravimetric_std': 0.0152906271,
#    'Cv_molar_mean': 9.294569,
#    'Cv_molar_std': 0.14151733},
#   {'id': 300,
#    'structure': '19020N3_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.3303563562,
#    'Cv_gravimetric_std': 0.0184799893,
#    'Cv_molar_mean': 12.312659,
#    'Cv_molar_std': 0.17103526},
#   {'id': 300,
#    'structure': '19020N3_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.3303563562,
#    'Cv_gravimetric_std': 0.0184799893,
#    'Cv_molar_mean': 12.312659,
#    'Cv_molar_std': 0.17103526},
#   {'id': 301,
#    'structure': '20051N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9576980051,
#    'Cv_gravimetric_std': 0.0032212753,
#    'Cv_molar_mean': 8.58261,
#    'Cv_molar_std': 0.028868046},
#   {'id': 301,
#    'structure': '20051N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9576980051,
#    'Cv_gravimetric_std': 0.0032212753,
#    'Cv_molar_mean': 8.58261,
#    'Cv_molar_std': 0.028868046},
#   {'id': 302,
#    'structure': '20051N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9969858313,
#    'Cv_gravimetric_std': 0.0053635316,
#    'Cv_molar_mean': 8.934696,
#    'Cv_molar_std': 0.04806636},
#   {'id': 302,
#    'structure': '20051N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9969858313,
#    'Cv_gravimetric_std': 0.0053635316,
#    'Cv_molar_mean': 8.934696,
#    'Cv_molar_std': 0.04806636},
#   {'id': 303,
#    'structure': '20051N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.3522195111,
#    'Cv_gravimetric_std': 0.002144001,
#    'Cv_molar_mean': 12.1181965,
#    'Cv_molar_std': 0.019214053},
#   {'id': 303,
#    'structure': '20051N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.3522195111,
#    'Cv_gravimetric_std': 0.002144001,
#    'Cv_molar_mean': 12.1181965,
#    'Cv_molar_std': 0.019214053},
#   {'id': 304,
#    'structure': '20590N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9625276335,
#    'Cv_gravimetric_std': 0.0074902333,
#    'Cv_molar_mean': 8.59376,
#    'Cv_molar_std': 0.06687535},
#   {'id': 304,
#    'structure': '20590N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9625276335,
#    'Cv_gravimetric_std': 0.0074902333,
#    'Cv_molar_mean': 8.59376,
#    'Cv_molar_std': 0.06687535},
#   {'id': 305,
#    'structure': '20590N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9996324844,
#    'Cv_gravimetric_std': 0.0074719298,
#    'Cv_molar_mean': 8.925043,
#    'Cv_molar_std': 0.06671171},
#   {'id': 305,
#    'structure': '20590N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9996324844,
#    'Cv_gravimetric_std': 0.0074719298,
#    'Cv_molar_mean': 8.925043,
#    'Cv_molar_std': 0.06671171},
#   {'id': 306,
#    'structure': '20590N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.3639931327,
#    'Cv_gravimetric_std': 0.0044384044,
#    'Cv_molar_mean': 12.178173,
#    'Cv_molar_std': 0.039627746},
#   {'id': 306,
#    'structure': '20590N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.3639931327,
#    'Cv_gravimetric_std': 0.0044384044,
#    'Cv_molar_mean': 12.178173,
#    'Cv_molar_std': 0.039627746},
#   {'id': 307,
#    'structure': '21030N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 1.0108740976,
#    'Cv_gravimetric_std': 0.0025927691,
#    'Cv_molar_mean': 8.096626,
#    'Cv_molar_std': 0.020766966},
#   {'id': 308,
#    'structure': '21030N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 1.0519863392,
#    'Cv_gravimetric_std': 0.0041622798,
#    'Cv_molar_mean': 8.425915,
#    'Cv_molar_std': 0.033337887},
#   {'id': 309,
#    'structure': '21030N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.4583937912,
#    'Cv_gravimetric_std': 0.0028486854,
#    'Cv_molar_mean': 11.681048,
#    'Cv_molar_std': 0.022816781},
#   {'id': 310,
#    'structure': '22108N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 1.0111819629,
#    'Cv_gravimetric_std': 0.002474929,
#    'Cv_molar_mean': 8.127898,
#    'Cv_molar_std': 0.019893512},
#   {'id': 310,
#    'structure': '22108N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 1.0111819629,
#    'Cv_gravimetric_std': 0.002474929,
#    'Cv_molar_mean': 8.127898,
#    'Cv_molar_std': 0.019893512},
#   {'id': 311,
#    'structure': '22108N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 1.0575112825,
#    'Cv_gravimetric_std': 0.0028383918,
#    'Cv_molar_mean': 8.500295,
#    'Cv_molar_std': 0.022815065},
#   {'id': 311,
#    'structure': '22108N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 1.0575112825,
#    'Cv_gravimetric_std': 0.0028383918,
#    'Cv_molar_mean': 8.500295,
#    'Cv_molar_std': 0.022815065},
#   {'id': 312,
#    'structure': '22108N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.4571029683,
#    'Cv_gravimetric_std': 0.0016512971,
#    'Cv_molar_mean': 11.712219,
#    'Cv_molar_std': 0.013273282},
#   {'id': 312,
#    'structure': '22108N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.4571029683,
#    'Cv_gravimetric_std': 0.0016512971,
#    'Cv_molar_mean': 11.712219,
#    'Cv_molar_std': 0.013273282},
#   {'id': 313,
#    'structure': '22221N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 1.0376494808,
#    'Cv_gravimetric_std': 0.004197603,
#    'Cv_molar_mean': 8.4235935,
#    'Cv_molar_std': 0.03407599},
#   {'id': 313,
#    'structure': '22221N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 1.0376494808,
#    'Cv_gravimetric_std': 0.004197603,
#    'Cv_molar_mean': 8.4235935,
#    'Cv_molar_std': 0.03407599},
#   {'id': 314,
#    'structure': '22221N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 1.0831200693,
#    'Cv_gravimetric_std': 0.0028824009,
#    'Cv_molar_mean': 8.792722,
#    'Cv_molar_std': 0.023399236},
#   {'id': 314,
#    'structure': '22221N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 1.0831200693,
#    'Cv_gravimetric_std': 0.0028824009,
#    'Cv_molar_mean': 8.792722,
#    'Cv_molar_std': 0.023399236},
#   {'id': 315,
#    'structure': '22221N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.4687855579,
#    'Cv_gravimetric_std': 0.0039677057,
#    'Cv_molar_mean': 11.923536,
#    'Cv_molar_std': 0.032209594},
#   {'id': 315,
#    'structure': '22221N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.4687855579,
#    'Cv_gravimetric_std': 0.0039677057,
#    'Cv_molar_mean': 11.923536,
#    'Cv_molar_std': 0.032209594},
#   {'id': 316,
#    'structure': '22551N2_ddec.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9716264374,
#    'Cv_gravimetric_std': 0.0020058756,
#    'Cv_molar_mean': 8.229108,
#    'Cv_molar_std': 0.016988723},
#   {'id': 317,
#    'structure': '22551N2_ddec.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 1.0140546459,
#    'Cv_gravimetric_std': 0.0030954553,
#    'Cv_molar_mean': 8.5884495,
#    'Cv_molar_std': 0.026216764},
#   {'id': 318,
#    'structure': '22551N2_ddec.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.3959510054,
#    'Cv_gravimetric_std': 0.0015361779,
#    'Cv_molar_mean': 11.822887,
#    'Cv_molar_std': 0.013010641},
#   {'id': 319,
#    'structure': 'ASEJOZ.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.5939817779,
#    'Cv_gravimetric_std': 0.0062452109,
#    'Cv_molar_mean': 11.044222,
#    'Cv_molar_std': 0.116120584},
#   {'id': 320,
#    'structure': 'ASEJOZ.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6108045576,
#    'Cv_gravimetric_std': 0.0078543433,
#    'Cv_molar_mean': 11.357016,
#    'Cv_molar_std': 0.14604005},
#   {'id': 321,
#    'structure': 'ASEJOZ.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.7716119624,
#    'Cv_gravimetric_std': 0.0037703175,
#    'Cv_molar_mean': 14.346994,
#    'Cv_molar_std': 0.0701035},
#   {'id': 322,
#    'structure': 'ASEJOZ01_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6129018151,
#    'Cv_gravimetric_std': 0.0125993991,
#    'Cv_molar_mean': 11.396012,
#    'Cv_molar_std': 0.23426747},
#   {'id': 323,
#    'structure': 'ASEJOZ01_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6126930798,
#    'Cv_gravimetric_std': 0.0121592701,
#    'Cv_molar_mean': 11.39213,
#    'Cv_molar_std': 0.22608371},
#   {'id': 324,
#    'structure': 'ASEJOZ01_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.7572462629,
#    'Cv_gravimetric_std': 0.014135715,
#    'Cv_molar_mean': 14.0798855,
#    'Cv_molar_std': 0.2628329},
#   {'id': 325,
#    'structure': 'AWASAU_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.4353461749,
#    'Cv_gravimetric_std': 0.0141208934,
#    'Cv_molar_mean': 11.509592,
#    'Cv_molar_std': 0.37332538},
#   {'id': 326,
#    'structure': 'AWASAU_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.4223548953,
#    'Cv_gravimetric_std': 0.0143733671,
#    'Cv_molar_mean': 11.166129,
#    'Cv_molar_std': 0.38},
#   {'id': 327,
#    'structure': 'AWASAU_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.5293317725,
#    'Cv_gravimetric_std': 0.0134197293,
#    'Cv_molar_mean': 13.994362,
#    'Cv_molar_std': 0.35478795},
#   {'id': 328,
#    'structure': 'AWASOI_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.4372232026,
#    'Cv_gravimetric_std': 0.0113498556,
#    'Cv_molar_mean': 11.559215,
#    'Cv_molar_std': 0.30006504},
#   {'id': 329,
#    'structure': 'AWASOI_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.4222532304,
#    'Cv_gravimetric_std': 0.0141507844,
#    'Cv_molar_mean': 11.163443,
#    'Cv_molar_std': 0.37411547},
#   {'id': 330,
#    'structure': 'AWASOI_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.528203162,
#    'Cv_gravimetric_std': 0.0143534779,
#    'Cv_molar_mean': 13.964523,
#    'Cv_molar_std': 0.37947437},
#   {'id': 331,
#    'structure': 'BETGUE_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.734361898,
#    'Cv_gravimetric_std': 0.0195106413,
#    'Cv_molar_mean': 10.58634,
#    'Cv_molar_std': 0.28125936},
#   {'id': 332,
#    'structure': 'BETGUE_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.7251295664,
#    'Cv_gravimetric_std': 0.0188111571,
#    'Cv_molar_mean': 10.453249,
#    'Cv_molar_std': 0.27117592},
#   {'id': 333,
#    'structure': 'BETGUE_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.9438735858,
#    'Cv_gravimetric_std': 0.0242960858,
#    'Cv_molar_mean': 13.606598,
#    'Cv_molar_std': 0.35024503},
#   {'id': 334,
#    'structure': 'CANRUG_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9119627058,
#    'Cv_gravimetric_std': 0.0408771433,
#    'Cv_molar_mean': 9.360062,
#    'Cv_molar_std': 0.4195485},
#   {'id': 335,
#    'structure': 'CANRUG_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.8983508907,
#    'Cv_gravimetric_std': 0.0293791816,
#    'Cv_molar_mean': 9.220355,
#    'Cv_molar_std': 0.30153742},
#   {'id': 336,
#    'structure': 'CANRUG_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.1823855266,
#    'Cv_gravimetric_std': 0.0402898313,
#    'Cv_molar_mean': 12.135585,
#    'Cv_molar_std': 0.4135205},
#   {'id': 337,
#    'structure': 'COCNAL_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.7068361531,
#    'Cv_gravimetric_std': 0.0221748318,
#    'Cv_molar_mean': 9.306017,
#    'Cv_molar_std': 0.29194808},
#   {'id': 338,
#    'structure': 'COCNAL_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6966839139,
#    'Cv_gravimetric_std': 0.020320778,
#    'Cv_molar_mean': 9.172356,
#    'Cv_molar_std': 0.26753795},
#   {'id': 339,
#    'structure': 'COCNAL_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.9345383518,
#    'Cv_gravimetric_std': 0.0251299243,
#    'Cv_molar_mean': 12.3038845,
#    'Cv_molar_std': 0.330854},
#   {'id': 340,
#    'structure': 'COYTIU_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.7056499326,
#    'Cv_gravimetric_std': 0.0097852158,
#    'Cv_molar_mean': 11.039049,
#    'Cv_molar_std': 0.15307802},
#   {'id': 341,
#    'structure': 'COYTIU_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6920068066,
#    'Cv_gravimetric_std': 0.0102871563,
#    'Cv_molar_mean': 10.825617,
#    'Cv_molar_std': 0.16093035},
#   {'id': 342,
#    'structure': 'COYTIU_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.8880295886,
#    'Cv_gravimetric_std': 0.0151965039,
#    'Cv_molar_mean': 13.89216,
#    'Cv_molar_std': 0.23773108},
#   {'id': 343,
#    'structure': 'COYTOA_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6778257394,
#    'Cv_gravimetric_std': 0.0096823672,
#    'Cv_molar_mean': 10.835228,
#    'Cv_molar_std': 0.1547752},
#   {'id': 344,
#    'structure': 'COYTOA_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6699452163,
#    'Cv_gravimetric_std': 0.0177092648,
#    'Cv_molar_mean': 10.709255,
#    'Cv_molar_std': 0.28308746},
#   {'id': 345,
#    'structure': 'COYTOA_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.8483590056,
#    'Cv_gravimetric_std': 0.0142923429,
#    'Cv_molar_mean': 13.561247,
#    'Cv_molar_std': 0.22846697},
#   {'id': 346,
#    'structure': 'DATPIY_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.5039999781,
#    'Cv_gravimetric_std': 0.0110610772,
#    'Cv_molar_mean': 11.826028,
#    'Cv_molar_std': 0.25954083},
#   {'id': 347,
#    'structure': 'DATPIY_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.5259279402,
#    'Cv_gravimetric_std': 0.0092827201,
#    'Cv_molar_mean': 12.340553,
#    'Cv_molar_std': 0.21781293},
#   {'id': 348,
#    'structure': 'DATPIY_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.6311993014,
#    'Cv_gravimetric_std': 0.0134378033,
#    'Cv_molar_mean': 14.810677,
#    'Cv_molar_std': 0.31530926},
#   {'id': 349,
#    'structure': 'DOMDAL_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6082447225,
#    'Cv_gravimetric_std': 0.0070416872,
#    'Cv_molar_mean': 13.694211,
#    'Cv_molar_std': 0.15853867},
#   {'id': 350,
#    'structure': 'DOMDAL_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6297250515,
#    'Cv_gravimetric_std': 0.0128451292,
#    'Cv_molar_mean': 14.177826,
#    'Cv_molar_std': 0.2891993},
#   {'id': 351,
#    'structure': 'DOMDAL_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.7205213771,
#    'Cv_gravimetric_std': 0.0125150749,
#    'Cv_molar_mean': 16.222042,
#    'Cv_molar_std': 0.28176817},
#   {'id': 352,
#    'structure': 'DOQGUM_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6094994352,
#    'Cv_gravimetric_std': 0.0117958781,
#    'Cv_molar_mean': 12.8349285,
#    'Cv_molar_std': 0.24839935},
#   {'id': 353,
#    'structure': 'DOQGUM_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6220557892,
#    'Cv_gravimetric_std': 0.0089682671,
#    'Cv_molar_mean': 13.099342,
#    'Cv_molar_std': 0.1888551},
#   {'id': 354,
#    'structure': 'DOQGUM_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.7276545649,
#    'Cv_gravimetric_std': 0.0128872763,
#    'Cv_molar_mean': 15.323056,
#    'Cv_molar_std': 0.27138218},
#   {'id': 355,
#    'structure': 'DOQHIB_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.5799629001,
#    'Cv_gravimetric_std': 0.0117064196,
#    'Cv_molar_mean': 12.406382,
#    'Cv_molar_std': 0.25042},
#   {'id': 356,
#    'structure': 'DOQHIB_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6083086717,
#    'Cv_gravimetric_std': 0.0082191543,
#    'Cv_molar_mean': 13.012744,
#    'Cv_molar_std': 0.17582153},
#   {'id': 357,
#    'structure': 'DOQHIB_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.7078008683,
#    'Cv_gravimetric_std': 0.0151224736,
#    'Cv_molar_mean': 15.14105,
#    'Cv_molar_std': 0.3234951},
#   {'id': 358,
#    'structure': 'ELILER_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.652475528,
#    'Cv_gravimetric_std': 0.0170305793,
#    'Cv_molar_mean': 10.145361,
#    'Cv_molar_std': 0.26480898},
#   {'id': 359,
#    'structure': 'ELILER_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6350738552,
#    'Cv_gravimetric_std': 0.0216558202,
#    'Cv_molar_mean': 9.874783,
#    'Cv_molar_std': 0.33672702},
#   {'id': 360,
#    'structure': 'ELILER_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.8195565946,
#    'Cv_gravimetric_std': 0.0260706113,
#    'Cv_molar_mean': 12.743311,
#    'Cv_molar_std': 0.40537265},
#   {'id': 361,
#    'structure': 'EXIBUI_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6716482915,
#    'Cv_gravimetric_std': 0.0110345446,
#    'Cv_molar_mean': 12.492299,
#    'Cv_molar_std': 0.20523666},
#   {'id': 362,
#    'structure': 'EXIBUI_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6619892753,
#    'Cv_gravimetric_std': 0.0102750466,
#    'Cv_molar_mean': 12.312646,
#    'Cv_molar_std': 0.19111037},
#   {'id': 363,
#    'structure': 'EXIBUI_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.8104474323,
#    'Cv_gravimetric_std': 0.0100377359,
#    'Cv_molar_mean': 15.073889,
#    'Cv_molar_std': 0.18669647},
#   {'id': 364,
#    'structure': 'GADFAV_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.610208729,
#    'Cv_gravimetric_std': 0.0091139257,
#    'Cv_molar_mean': 14.443599,
#    'Cv_molar_std': 0.21572605},
#   {'id': 365,
#    'structure': 'GADFAV_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6242537666,
#    'Cv_gravimetric_std': 0.0114831219,
#    'Cv_molar_mean': 14.776042,
#    'Cv_molar_std': 0.2718046},
#   {'id': 366,
#    'structure': 'GADFAV_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.7277015471,
#    'Cv_gravimetric_std': 0.0083344269,
#    'Cv_molar_mean': 17.224644,
#    'Cv_molar_std': 0.19727512},
#   {'id': 367,
#    'structure': 'GAJYUN_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6849871995,
#    'Cv_gravimetric_std': 0.0416549636,
#    'Cv_molar_mean': 9.491175,
#    'Cv_molar_std': 0.5771708},
#   {'id': 368,
#    'structure': 'GAJYUN_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6978421224,
#    'Cv_gravimetric_std': 0.0367809575,
#    'Cv_molar_mean': 9.669292,
#    'Cv_molar_std': 0.50963646},
#   {'id': 369,
#    'structure': 'GAJYUN_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.8387932487,
#    'Cv_gravimetric_std': 0.0526500434,
#    'Cv_molar_mean': 11.62231,
#    'Cv_molar_std': 0.7295185},
#   {'id': 370,
#    'structure': 'GAJZEY_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6748314759,
#    'Cv_gravimetric_std': 0.039689704,
#    'Cv_molar_mean': 9.457548,
#    'Cv_molar_std': 0.5562386},
#   {'id': 371,
#    'structure': 'GAJZEY_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6795600285,
#    'Cv_gravimetric_std': 0.0396510481,
#    'Cv_molar_mean': 9.523817,
#    'Cv_molar_std': 0.5556969},
#   {'id': 372,
#    'structure': 'GAJZEY_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.8329313776,
#    'Cv_gravimetric_std': 0.0448704428,
#    'Cv_molar_mean': 11.673266,
#    'Cv_molar_std': 0.628845},
#   {'id': 373,
#    'structure': 'HOWROC_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6158612786,
#    'Cv_gravimetric_std': 0.0149864538,
#    'Cv_molar_mean': 10.889894,
#    'Cv_molar_std': 0.26499602},
#   {'id': 374,
#    'structure': 'HOWROC_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6120800871,
#    'Cv_gravimetric_std': 0.0169859068,
#    'Cv_molar_mean': 10.823033,
#    'Cv_molar_std': 0.30035132},
#   {'id': 375,
#    'structure': 'HOWROC_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.7544084926,
#    'Cv_gravimetric_std': 0.0192155926,
#    'Cv_molar_mean': 13.339737,
#    'Cv_molar_std': 0.33977744},
#   {'id': 376,
#    'structure': 'KIBDEF_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.5365098283,
#    'Cv_gravimetric_std': 0.0173163795,
#    'Cv_molar_mean': 11.881001,
#    'Cv_molar_std': 0.38347092},
#   {'id': 377,
#    'structure': 'KIBDEF_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.548502493,
#    'Cv_gravimetric_std': 0.0204594559,
#    'Cv_molar_mean': 12.146579,
#    'Cv_molar_std': 0.4530743},
#   {'id': 378,
#    'structure': 'KIBDEF_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.6643839902,
#    'Cv_gravimetric_std': 0.0166767368,
#    'Cv_molar_mean': 14.712774,
#    'Cv_molar_std': 0.36930597},
#   {'id': 379,
#    'structure': 'KIBDIJ_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.5331412435,
#    'Cv_gravimetric_std': 0.0166931964,
#    'Cv_molar_mean': 12.071504,
#    'Cv_molar_std': 0.37797105},
#   {'id': 380,
#    'structure': 'KIBDIJ_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.5316922534,
#    'Cv_gravimetric_std': 0.0220466183,
#    'Cv_molar_mean': 12.038695,
#    'Cv_molar_std': 0.4991845},
#   {'id': 381,
#    'structure': 'KIBDIJ_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.6462887636,
#    'Cv_gravimetric_std': 0.0140659265,
#    'Cv_molar_mean': 14.633413,
#    'Cv_molar_std': 0.31848395},
#   {'id': 382,
#    'structure': 'LADWAR_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.729342155,
#    'Cv_gravimetric_std': 0.0153880481,
#    'Cv_molar_mean': 12.02228,
#    'Cv_molar_std': 0.25365242},
#   {'id': 383,
#    'structure': 'LADWAR_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.7216562743,
#    'Cv_gravimetric_std': 0.0138701474,
#    'Cv_molar_mean': 11.895587,
#    'Cv_molar_std': 0.22863166},
#   {'id': 384,
#    'structure': 'LADWAR_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.908354063,
#    'Cv_gravimetric_std': 0.0059304371,
#    'Cv_molar_mean': 14.973063,
#    'Cv_molar_std': 0.09775559},
#   {'id': 385,
#    'structure': 'LAGNAK_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.7951277888,
#    'Cv_gravimetric_std': 0.0255305034,
#    'Cv_molar_mean': 10.657203,
#    'Cv_molar_std': 0.3421886},
#   {'id': 386,
#    'structure': 'LAGNAK_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.7594919957,
#    'Cv_gravimetric_std': 0.0187367904,
#    'Cv_molar_mean': 10.179571,
#    'Cv_molar_std': 0.25113165},
#   {'id': 387,
#    'structure': 'LAGNAK_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.9866365963,
#    'Cv_gravimetric_std': 0.0351593357,
#    'Cv_molar_mean': 13.22402,
#    'Cv_molar_std': 0.4712451},
#   {'id': 388,
#    'structure': 'LAGQER_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6373360953,
#    'Cv_gravimetric_std': 0.0146452216,
#    'Cv_molar_mean': 10.108976,
#    'Cv_molar_std': 0.23229228},
#   {'id': 389,
#    'structure': 'LAGQER_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6382950884,
#    'Cv_gravimetric_std': 0.0221342647,
#    'Cv_molar_mean': 10.124189,
#    'Cv_molar_std': 0.35107824},
#   {'id': 390,
#    'structure': 'LAGQER_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.8045562291,
#    'Cv_gravimetric_std': 0.0309979141,
#    'Cv_molar_mean': 12.761305,
#    'Cv_molar_std': 0.49166697},
#   {'id': 391,
#    'structure': 'MEHMET_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.8348755208,
#    'Cv_gravimetric_std': 0.0240166807,
#    'Cv_molar_mean': 10.879704,
#    'Cv_molar_std': 0.31297398},
#   {'id': 392,
#    'structure': 'MEHMET_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.813426305,
#    'Cv_gravimetric_std': 0.0159302226,
#    'Cv_molar_mean': 10.600188,
#    'Cv_molar_std': 0.20759515},
#   {'id': 393,
#    'structure': 'MEHMET_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.0506156955,
#    'Cv_gravimetric_std': 0.0197130532,
#    'Cv_molar_mean': 13.691129,
#    'Cv_molar_std': 0.2568913},
#   {'id': 394,
#    'structure': 'MIFSAX_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.7337359655,
#    'Cv_gravimetric_std': 0.0201511881,
#    'Cv_molar_mean': 9.7053,
#    'Cv_molar_std': 0.26654473},
#   {'id': 395,
#    'structure': 'MIFSAX_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.7263976146,
#    'Cv_gravimetric_std': 0.0246261612,
#    'Cv_molar_mean': 9.608235,
#    'Cv_molar_std': 0.32573608},
#   {'id': 396,
#    'structure': 'MIFSAX_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.9416870354,
#    'Cv_gravimetric_std': 0.0292702975,
#    'Cv_molar_mean': 12.455919,
#    'Cv_molar_std': 0.38716513},
#   {'id': 397,
#    'structure': 'MOLRIP_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6111534387,
#    'Cv_gravimetric_std': 0.011702821,
#    'Cv_molar_mean': 11.40044,
#    'Cv_molar_std': 0.21830416},
#   {'id': 398,
#    'structure': 'MOLRIP_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.623655841,
#    'Cv_gravimetric_std': 0.0145773674,
#    'Cv_molar_mean': 11.633659,
#    'Cv_molar_std': 0.2719259},
#   {'id': 399,
#    'structure': 'MOLRIP_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.7632440187,
#    'Cv_gravimetric_std': 0.0119124547,
#    'Cv_molar_mean': 14.237534,
#    'Cv_molar_std': 0.22221455},
#   {'id': 400,
#    'structure': 'MOTMAK.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 1.0835711001,
#    'Cv_gravimetric_std': 0.0119309287,
#    'Cv_molar_mean': 10.715132,
#    'Cv_molar_std': 0.117981516},
#   {'id': 401,
#    'structure': 'MOTMAK.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 1.1139811945,
#    'Cv_gravimetric_std': 0.0063440729,
#    'Cv_molar_mean': 11.015848,
#    'Cv_molar_std': 0.06273481},
#   {'id': 402,
#    'structure': 'MOTMAK.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.4327264457,
#    'Cv_gravimetric_std': 0.0064526494,
#    'Cv_molar_mean': 14.1678295,
#    'Cv_molar_std': 0.06380836},
#   {'id': 403,
#    'structure': 'MUGXIX_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.7085537085,
#    'Cv_gravimetric_std': 0.0353365834,
#    'Cv_molar_mean': 8.649019,
#    'Cv_molar_std': 0.431339},
#   {'id': 404,
#    'structure': 'MUGXIX_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.7107733801,
#    'Cv_gravimetric_std': 0.0376528065,
#    'Cv_molar_mean': 8.676114,
#    'Cv_molar_std': 0.45961204},
#   {'id': 405,
#    'structure': 'MUGXIX_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.9204432693,
#    'Cv_gravimetric_std': 0.0396326439,
#    'Cv_molar_mean': 11.235467,
#    'Cv_molar_std': 0.48377925},
#   {'id': 406,
#    'structure': 'NARPOO_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6238598074,
#    'Cv_gravimetric_std': 0.0069746258,
#    'Cv_molar_mean': 12.352995,
#    'Cv_molar_std': 0.13810408},
#   {'id': 407,
#    'structure': 'NARPOO_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6460209139,
#    'Cv_gravimetric_std': 0.0084568048,
#    'Cv_molar_mean': 12.791804,
#    'Cv_molar_std': 0.16745268},
#   {'id': 408,
#    'structure': 'NARPOO_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.7972158465,
#    'Cv_gravimetric_std': 0.0069266416,
#    'Cv_molar_mean': 15.785602,
#    'Cv_molar_std': 0.13715382},
#   {'id': 409,
#    'structure': 'NEPWIQ_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.5189610045,
#    'Cv_gravimetric_std': 0.0159482655,
#    'Cv_molar_mean': 12.059348,
#    'Cv_molar_std': 0.37059754},
#   {'id': 410,
#    'structure': 'NEPWIQ_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.5186447922,
#    'Cv_gravimetric_std': 0.0175553781,
#    'Cv_molar_mean': 12.052,
#    'Cv_molar_std': 0.40794277},
#   {'id': 411,
#    'structure': 'NEPWIQ_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.6333119691,
#    'Cv_gravimetric_std': 0.0156027795,
#    'Cv_molar_mean': 14.716578,
#    'Cv_molar_std': 0.36256918},
#   {'id': 412,
#    'structure': 'NOCLUN_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.7205280442,
#    'Cv_gravimetric_std': 0.0269716863,
#    'Cv_molar_mean': 10.669535,
#    'Cv_molar_std': 0.39939508},
#   {'id': 413,
#    'structure': 'NOCLUN_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.7144638725,
#    'Cv_gravimetric_std': 0.0291008648,
#    'Cv_molar_mean': 10.579737,
#    'Cv_molar_std': 0.4309239},
#   {'id': 414,
#    'structure': 'NOCLUN_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.8982896706,
#    'Cv_gravimetric_std': 0.0277371839,
#    'Cv_molar_mean': 13.301817,
#    'Cv_molar_std': 0.41073057},
#   {'id': 415,
#    'structure': 'NOCYUB_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.7459128886,
#    'Cv_gravimetric_std': 0.0130675806,
#    'Cv_molar_mean': 11.436228,
#    'Cv_molar_std': 0.20035027},
#   {'id': 416,
#    'structure': 'NOCYUB_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.7211616925,
#    'Cv_gravimetric_std': 0.012090576,
#    'Cv_molar_mean': 11.0567465,
#    'Cv_molar_std': 0.18537097},
#   {'id': 417,
#    'structure': 'NOCYUB_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.9226024149,
#    'Cv_gravimetric_std': 0.0162720665,
#    'Cv_molar_mean': 14.145207,
#    'Cv_molar_std': 0.249481},
#   {'id': 418,
#    'structure': 'NaCl_P1.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.4965421574,
#    'Cv_gravimetric_std': 0.0068022741,
#    'Cv_molar_mean': 14.509649,
#    'Cv_molar_std': 0.19877188},
#   {'id': 419,
#    'structure': 'NaCl_P1.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.5094684893,
#    'Cv_gravimetric_std': 0.0069799094,
#    'Cv_molar_mean': 14.887375,
#    'Cv_molar_std': 0.20396261},
#   {'id': 420,
#    'structure': 'NaCl_P1.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.5905638113,
#    'Cv_gravimetric_std': 0.0649230957,
#    'Cv_molar_mean': 17.257092,
#    'Cv_molar_std': 1.8971428},
#   {'id': 421,
#    'structure': 'NbOFFIVE-1-Ni.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.7030268747,
#    'Cv_gravimetric_std': 0.0119173439,
#    'Cv_molar_mean': 10.614881,
#    'Cv_molar_std': 0.17993794},
#   {'id': 421,
#    'structure': 'NbOFFIVE-1-Ni.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.7030268747,
#    'Cv_gravimetric_std': 0.0119173439,
#    'Cv_molar_mean': 10.614881,
#    'Cv_molar_std': 0.17993794},
#   {'id': 422,
#    'structure': 'NbOFFIVE-1-Ni.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.7321606664,
#    'Cv_gravimetric_std': 0.01051121,
#    'Cv_molar_mean': 11.054767,
#    'Cv_molar_std': 0.15870693},
#   {'id': 422,
#    'structure': 'NbOFFIVE-1-Ni.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.7321606664,
#    'Cv_gravimetric_std': 0.01051121,
#    'Cv_molar_mean': 11.054767,
#    'Cv_molar_std': 0.15870693},
#   {'id': 423,
#    'structure': 'NbOFFIVE-1-Ni.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.933267984,
#    'Cv_gravimetric_std': 0.0062002269,
#    'Cv_molar_mean': 14.09125,
#    'Cv_molar_std': 0.09361608},
#   {'id': 423,
#    'structure': 'NbOFFIVE-1-Ni.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.933267984,
#    'Cv_gravimetric_std': 0.0062002269,
#    'Cv_molar_mean': 14.09125,
#    'Cv_molar_std': 0.09361608},
#   {'id': 424,
#    'structure': 'ODAJAG_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6228481299,
#    'Cv_gravimetric_std': 0.0209190562,
#    'Cv_molar_mean': 11.637656,
#    'Cv_molar_std': 0.3908637},
#   {'id': 425,
#    'structure': 'ODAJAG_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6452607188,
#    'Cv_gravimetric_std': 0.0145988138,
#    'Cv_molar_mean': 12.056426,
#    'Cv_molar_std': 0.2727726},
#   {'id': 426,
#    'structure': 'ODAJAG_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.7745495227,
#    'Cv_gravimetric_std': 0.0137166022,
#    'Cv_molar_mean': 14.472133,
#    'Cv_molar_std': 0.25628904},
#   {'id': 427,
#    'structure': 'OSAVUA_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9175735787,
#    'Cv_gravimetric_std': 0.0251075329,
#    'Cv_molar_mean': 11.40649,
#    'Cv_molar_std': 0.3121154},
#   {'id': 428,
#    'structure': 'OSAVUA_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.8829968415,
#    'Cv_gravimetric_std': 0.0265806874,
#    'Cv_molar_mean': 10.976663,
#    'Cv_molar_std': 0.33042845},
#   {'id': 429,
#    'structure': 'OSAVUA_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.1076482147,
#    'Cv_gravimetric_std': 0.0333448169,
#    'Cv_molar_mean': 13.769336,
#    'Cv_molar_std': 0.41451436},
#   {'id': 430,
#    'structure': 'OZAVES_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.8221193594,
#    'Cv_gravimetric_std': 0.0140803509,
#    'Cv_molar_mean': 12.3447485,
#    'Cv_molar_std': 0.21142708},
#   {'id': 431,
#    'structure': 'OZAVES_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.813534863,
#    'Cv_gravimetric_std': 0.0143163081,
#    'Cv_molar_mean': 12.215846,
#    'Cv_molar_std': 0.21497034},
#   {'id': 432,
#    'structure': 'OZAVES_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.0073614248,
#    'Cv_gravimetric_std': 0.016982088,
#    'Cv_molar_mean': 15.1263,
#    'Cv_molar_std': 0.2549991},
#   {'id': 433,
#    'structure': 'PAMHES01_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.7769565152,
#    'Cv_gravimetric_std': 0.0074121218,
#    'Cv_molar_mean': 11.726298,
#    'Cv_molar_std': 0.11186814},
#   {'id': 434,
#    'structure': 'PAMHES01_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.7663523277,
#    'Cv_gravimetric_std': 0.0128534327,
#    'Cv_molar_mean': 11.566255,
#    'Cv_molar_std': 0.19399177},
#   {'id': 435,
#    'structure': 'PAMHES01_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.9701930704,
#    'Cv_gravimetric_std': 0.0117183347,
#    'Cv_molar_mean': 14.642741,
#    'Cv_molar_std': 0.1768604},
#   {'id': 436,
#    'structure': 'PEGPUO_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.5353975204,
#    'Cv_gravimetric_std': 0.0069910169,
#    'Cv_molar_mean': 12.107401,
#    'Cv_molar_std': 0.15809381},
#   {'id': 437,
#    'structure': 'PEGPUO_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.5443016113,
#    'Cv_gravimetric_std': 0.0092678428,
#    'Cv_molar_mean': 12.308757,
#    'Cv_molar_std': 0.20958167},
#   {'id': 438,
#    'structure': 'PEGPUO_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.6696394971,
#    'Cv_gravimetric_std': 0.0064744622,
#    'Cv_molar_mean': 15.143129,
#    'Cv_molar_std': 0.14641255},
#   {'id': 439,
#    'structure': 'PEGQAV_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.5307384298,
#    'Cv_gravimetric_std': 0.0060137472,
#    'Cv_molar_mean': 12.13817,
#    'Cv_molar_std': 0.13753639},
#   {'id': 440,
#    'structure': 'PEGQAV_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.540939936,
#    'Cv_gravimetric_std': 0.008408841,
#    'Cv_molar_mean': 12.371481,
#    'Cv_molar_std': 0.19231313},
#   {'id': 441,
#    'structure': 'PEGQAV_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.6639406343,
#    'Cv_gravimetric_std': 0.0054300883,
#    'Cv_molar_mean': 15.184549,
#    'Cv_molar_std': 0.12418804},
#   {'id': 442,
#    'structure': 'QATRAG_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6459360165,
#    'Cv_gravimetric_std': 0.0100387203,
#    'Cv_molar_mean': 11.92098,
#    'Cv_molar_std': 0.18526801},
#   {'id': 443,
#    'structure': 'QATRAG_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6584473969,
#    'Cv_gravimetric_std': 0.0110109347,
#    'Cv_molar_mean': 12.151883,
#    'Cv_molar_std': 0.20321077},
#   {'id': 444,
#    'structure': 'QATRAG_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.7909442595,
#    'Cv_gravimetric_std': 0.0188298421,
#    'Cv_molar_mean': 14.597158,
#    'Cv_molar_std': 0.34751144},
#   {'id': 445,
#    'structure': 'RANNUS_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.7829781743,
#    'Cv_gravimetric_std': 0.0189556349,
#    'Cv_molar_mean': 10.71412,
#    'Cv_molar_std': 0.2593854},
#   {'id': 446,
#    'structure': 'RANNUS_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.7579645347,
#    'Cv_gravimetric_std': 0.0179598493,
#    'Cv_molar_mean': 10.371839,
#    'Cv_molar_std': 0.24575894},
#   {'id': 447,
#    'structure': 'RANNUS_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.9571205172,
#    'Cv_gravimetric_std': 0.037905425,
#    'Cv_molar_mean': 13.097051,
#    'Cv_molar_std': 0.5186904},
#   {'id': 448,
#    'structure': 'RASXEP01_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.5106128118,
#    'Cv_gravimetric_std': 0.0119832858,
#    'Cv_molar_mean': 11.918192,
#    'Cv_molar_std': 0.2797013},
#   {'id': 449,
#    'structure': 'RASXEP01_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.5292824587,
#    'Cv_gravimetric_std': 0.0082823093,
#    'Cv_molar_mean': 12.353959,
#    'Cv_molar_std': 0.19331706},
#   {'id': 450,
#    'structure': 'RASXEP01_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.6391382236,
#    'Cv_gravimetric_std': 0.0138191827,
#    'Cv_molar_mean': 14.918097,
# ...
#   {'id': 488,
#    'structure': 'UREVOE_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6317653104,
#    'Cv_gravimetric_std': 0.0154485678,
#    'Cv_molar_mean': 10.700075,
#    'Cv_molar_std': 0.261649},
#   {'id': 489,
#    'structure': 'UREVOE_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.7970440975,
#    'Cv_gravimetric_std': 0.0174400113,
#    'Cv_molar_mean': 13.499367,
#    'Cv_molar_std': 0.29537773},
#   {'id': 490,
#    'structure': 'WEFZIS_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.5893030403,
#    'Cv_gravimetric_std': 0.0173257477,
#    'Cv_molar_mean': 11.687781,
#    'Cv_molar_std': 0.34362552},
#   {'id': 491,
#    'structure': 'WEFZIS_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.5759752384,
#    'Cv_gravimetric_std': 0.0194704554,
#    'Cv_molar_mean': 11.423449,
#    'Cv_molar_std': 0.386162},
#   {'id': 492,
#    'structure': 'WEFZIS_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.6974247547,
#    'Cv_gravimetric_std': 0.02825568,
#    'Cv_molar_mean': 13.832184,
#    'Cv_molar_std': 0.5604014},
#   {'id': 493,
#    'structure': 'WOHZAU_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6456781695,
#    'Cv_gravimetric_std': 0.024013831,
#    'Cv_molar_mean': 9.825236,
#    'Cv_molar_std': 0.36541674},
#   {'id': 494,
#    'structure': 'WOHZAU_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6500692966,
#    'Cv_gravimetric_std': 0.0247287251,
#    'Cv_molar_mean': 9.892056,
#    'Cv_molar_std': 0.37629512},
#   {'id': 495,
#    'structure': 'WOHZAU_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.8103251122,
#    'Cv_gravimetric_std': 0.0377642759,
#    'Cv_molar_mean': 12.330657,
#    'Cv_molar_std': 0.57465625},
#   {'id': 496,
#    'structure': 'YITHOA01_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6298244731,
#    'Cv_gravimetric_std': 0.0146139208,
#    'Cv_molar_mean': 12.100485,
#    'Cv_molar_std': 0.28076965},
#   {'id': 497,
#    'structure': 'YITHOA01_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6365326159,
#    'Cv_gravimetric_std': 0.016831908,
#    'Cv_molar_mean': 12.229365,
#    'Cv_molar_std': 0.3233826},
#   {'id': 498,
#    'structure': 'YITHOA01_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.7691083754,
#    'Cv_gravimetric_std': 0.0136414136,
#    'Cv_molar_mean': 14.776474,
#    'Cv_molar_std': 0.2620851},
#   {'id': 499,
#    'structure': 'YOCSEQ_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.5593265084,
#    'Cv_gravimetric_std': 0.0115323764,
#    'Cv_molar_mean': 11.32912,
#    'Cv_molar_std': 0.23358755},
#   {'id': 500,
#    'structure': 'YOCSEQ_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.5705862646,
#    'Cv_gravimetric_std': 0.016625126,
#    'Cv_molar_mean': 11.557185,
#    'Cv_molar_std': 0.33674088},
#   {'id': 501,
#    'structure': 'YOCSEQ_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.6885709575,
#    'Cv_gravimetric_std': 0.012284343,
#    'Cv_molar_mean': 13.946958,
#    'Cv_molar_std': 0.2488185},
#   {'id': 502,
#    'structure': 'ZEZPAX01_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6625958448,
#    'Cv_gravimetric_std': 0.0128338626,
#    'Cv_molar_mean': 10.663039,
#    'Cv_molar_std': 0.20653313},
#   {'id': 503,
#    'structure': 'ZEZPAX01_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.651986785,
#    'Cv_gravimetric_std': 0.0156268893,
#    'Cv_molar_mean': 10.49231,
#    'Cv_molar_std': 0.25148073},
#   {'id': 504,
#    'structure': 'ZEZPAX01_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.8386216206,
#    'Cv_gravimetric_std': 0.0181565315,
#    'Cv_molar_mean': 13.495791,
#    'Cv_molar_std': 0.29218984},
#   {'id': 505,
#    'structure': 'ZEZPOL_clean.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.669558091,
#    'Cv_gravimetric_std': 0.0118621032,
#    'Cv_molar_mean': 10.531824,
#    'Cv_molar_std': 0.18658517},
#   {'id': 506,
#    'structure': 'ZEZPOL_clean.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6634135237,
#    'Cv_gravimetric_std': 0.0198457091,
#    'Cv_molar_mean': 10.435173,
#    'Cv_molar_std': 0.3121633},
#   {'id': 507,
#    'structure': 'ZEZPOL_clean.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.843052495,
#    'Cv_gravimetric_std': 0.0253073778,
#    'Cv_molar_mean': 13.260808,
#    'Cv_molar_std': 0.39807278},
#   {'id': 508,
#    'structure': 'cau10-nh2.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.931992442,
#    'Cv_gravimetric_std': 0.0094485413,
#    'Cv_molar_mean': 9.90213,
#    'Cv_molar_std': 0.100387976},
#   {'id': 508,
#    'structure': 'cau10-nh2.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.931992442,
#    'Cv_gravimetric_std': 0.0094485413,
#    'Cv_molar_mean': 9.90213,
#    'Cv_molar_std': 0.100387976},
#   {'id': 509,
#    'structure': 'cau10-nh2.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9689186555,
#    'Cv_gravimetric_std': 0.0155790029,
#    'Cv_molar_mean': 10.29446,
#    'Cv_molar_std': 0.16552207},
#   {'id': 509,
#    'structure': 'cau10-nh2.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9689186555,
#    'Cv_gravimetric_std': 0.0155790029,
#    'Cv_molar_mean': 10.29446,
#    'Cv_molar_std': 0.16552207},
#   {'id': 510,
#    'structure': 'cau10-nh2.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.2572664141,
#    'Cv_gravimetric_std': 0.0209966541,
#    'Cv_molar_mean': 13.358066,
#    'Cv_molar_std': 0.22308303},
#   {'id': 510,
#    'structure': 'cau10-nh2.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.2572664141,
#    'Cv_gravimetric_std': 0.0209966541,
#    'Cv_molar_mean': 13.358066,
#    'Cv_molar_std': 0.22308303},
#   {'id': 511,
#    'structure': 'koslub_P1_fixed.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.6750902529,
#    'Cv_gravimetric_std': 0.0190413915,
#    'Cv_molar_mean': 11.682238,
#    'Cv_molar_std': 0.32950562},
#   {'id': 512,
#    'structure': 'koslub_P1_fixed.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.6971145578,
#    'Cv_gravimetric_std': 0.0079708517,
#    'Cv_molar_mean': 12.06336,
#    'Cv_molar_std': 0.13793324},
#   {'id': 513,
#    'structure': 'koslub_P1_fixed.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 0.8642032207,
#    'Cv_gravimetric_std': 0.008022538,
#    'Cv_molar_mean': 14.954781,
#    'Cv_molar_std': 0.13882774},
#   {'id': 514,
#    'structure': 'qmof-02d74bc.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9321232358,
#    'Cv_gravimetric_std': 0.0046487093,
#    'Cv_molar_mean': 9.933494,
#    'Cv_molar_std': 0.04954067},
#   {'id': 514,
#    'structure': 'qmof-02d74bc.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9321232358,
#    'Cv_gravimetric_std': 0.0046487093,
#    'Cv_molar_mean': 9.933494,
#    'Cv_molar_std': 0.04954067},
#   {'id': 515,
#    'structure': 'qmof-02d74bc.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9392261106,
#    'Cv_gravimetric_std': 0.006068576,
#    'Cv_molar_mean': 10.009188,
#    'Cv_molar_std': 0.064672045},
#   {'id': 515,
#    'structure': 'qmof-02d74bc.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9392261106,
#    'Cv_gravimetric_std': 0.006068576,
#    'Cv_molar_mean': 10.009188,
#    'Cv_molar_std': 0.064672045},
#   {'id': 516,
#    'structure': 'qmof-02d74bc.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.2526432863,
#    'Cv_gravimetric_std': 0.0053349172,
#    'Cv_molar_mean': 13.349226,
#    'Cv_molar_std': 0.05685346},
#   {'id': 516,
#    'structure': 'qmof-02d74bc.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.2526432863,
#    'Cv_gravimetric_std': 0.0053349172,
#    'Cv_molar_mean': 13.349226,
#    'Cv_molar_std': 0.05685346},
#   {'id': 517,
#    'structure': 'qmof-0a464a7.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9370168126,
#    'Cv_gravimetric_std': 0.0126519178,
#    'Cv_molar_mean': 9.55821,
#    'Cv_molar_std': 0.12905824},
#   {'id': 518,
#    'structure': 'qmof-0a464a7.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9757615458,
#    'Cv_gravimetric_std': 0.0096371046,
#    'Cv_molar_mean': 9.953432,
#    'Cv_molar_std': 0.09830508},
#   {'id': 519,
#    'structure': 'qmof-0a464a7.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.2728394038,
#    'Cv_gravimetric_std': 0.0092713442,
#    'Cv_molar_mean': 12.98383,
#    'Cv_molar_std': 0.094574},
#   {'id': 520,
#    'structure': 'qmof-1da6c76.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.903221887,
#    'Cv_gravimetric_std': 0.0047042319,
#    'Cv_molar_mean': 9.576922,
#    'Cv_molar_std': 0.049879268},
#   {'id': 521,
#    'structure': 'qmof-1da6c76.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9318427126,
#    'Cv_gravimetric_std': 0.00282274,
#    'Cv_molar_mean': 9.880391,
#    'Cv_molar_std': 0.029929727},
#   {'id': 522,
#    'structure': 'qmof-1da6c76.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.218913842,
#    'Cv_gravimetric_std': 0.0039335656,
#    'Cv_molar_mean': 12.924225,
#    'Cv_molar_std': 0.041707773},
#   {'id': 523,
#    'structure': 'qmof-3beea42.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 1.0138370183,
#    'Cv_gravimetric_std': 0.0155415395,
#    'Cv_molar_mean': 9.166285,
#    'Cv_molar_std': 0.14051394},
#   {'id': 524,
#    'structure': 'qmof-3beea42.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 1.0666522848,
#    'Cv_gravimetric_std': 0.008043277,
#    'Cv_molar_mean': 9.643798,
#    'Cv_molar_std': 0.07272073},
#   {'id': 525,
#    'structure': 'qmof-3beea42.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.3854599574,
#    'Cv_gravimetric_std': 0.0133588405,
#    'Cv_molar_mean': 12.526196,
#    'Cv_molar_std': 0.12077974},
#   {'id': 526,
#    'structure': 'qmof-798e431.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.8837151242,
#    'Cv_gravimetric_std': 0.0091322314,
#    'Cv_molar_mean': 9.2730665,
#    'Cv_molar_std': 0.09582715},
#   {'id': 527,
#    'structure': 'qmof-798e431.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9218174943,
#    'Cv_gravimetric_std': 0.0070214106,
#    'Cv_molar_mean': 9.672886,
#    'Cv_molar_std': 0.07367741},
#   {'id': 528,
#    'structure': 'qmof-798e431.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.1986433366,
#    'Cv_gravimetric_std': 0.0057367211,
#    'Cv_molar_mean': 12.577696,
#    'Cv_molar_std': 0.060196992},
#   {'id': 529,
#    'structure': 'qmof-7c567fa.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.8833380709,
#    'Cv_gravimetric_std': 0.0121888264,
#    'Cv_molar_mean': 9.637983,
#    'Cv_molar_std': 0.13299073},
#   {'id': 530,
#    'structure': 'qmof-7c567fa.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9136966734,
#    'Cv_gravimetric_std': 0.0120104853,
#    'Cv_molar_mean': 9.969221,
#    'Cv_molar_std': 0.13104491},
#   {'id': 531,
#    'structure': 'qmof-7c567fa.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.1923257092,
#    'Cv_gravimetric_std': 0.0135209029,
#    'Cv_molar_mean': 13.009306,
#    'Cv_molar_std': 0.14752458},
#   {'id': 532,
#    'structure': 'qmof-97d5d0e.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.8947247955,
#    'Cv_gravimetric_std': 0.0059528819,
#    'Cv_molar_mean': 9.28462,
#    'Cv_molar_std': 0.061773445},
#   {'id': 533,
#    'structure': 'qmof-97d5d0e.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9289167975,
#    'Cv_gravimetric_std': 0.0046433364,
#    'Cv_molar_mean': 9.639432,
#    'Cv_molar_std': 0.0481842},
#   {'id': 534,
#    'structure': 'qmof-97d5d0e.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.2288265809,
#    'Cv_gravimetric_std': 0.0074979033,
#    'Cv_molar_mean': 12.7516165,
#    'Cv_molar_std': 0.07780626},
#   {'id': 535,
#    'structure': 'qmof-9fd01d7.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.911759338,
#    'Cv_gravimetric_std': 0.0143250381,
#    'Cv_molar_mean': 9.26602,
#    'Cv_molar_std': 0.14558247},
#   {'id': 536,
#    'structure': 'qmof-9fd01d7.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9562732807,
#    'Cv_gravimetric_std': 0.0139690517,
#    'Cv_molar_mean': 9.718407,
#    'Cv_molar_std': 0.14196454},
#   {'id': 537,
#    'structure': 'qmof-9fd01d7.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.2271813422,
#    'Cv_gravimetric_std': 0.0103095866,
#    'Cv_molar_mean': 12.471589,
#    'Cv_molar_std': 0.104774125},
#   {'id': 538,
#    'structure': 'qmof-b4192d1.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9108128327,
#    'Cv_gravimetric_std': 0.0072519171,
#    'Cv_molar_mean': 9.065893,
#    'Cv_molar_std': 0.07218292},
#   {'id': 539,
#    'structure': 'qmof-b4192d1.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9356737424,
#    'Cv_gravimetric_std': 0.005131114,
#    'Cv_molar_mean': 9.313351,
#    'Cv_molar_std': 0.05107324},
#   {'id': 540,
#    'structure': 'qmof-b4192d1.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.2467411837,
#    'Cv_gravimetric_std': 0.0106414263,
#    'Cv_molar_mean': 12.4096,
#    'Cv_molar_std': 0.10592072},
#   {'id': 541,
#    'structure': 'qmof-cb9ea13.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.9099055304,
#    'Cv_gravimetric_std': 0.0104876406,
#    'Cv_molar_mean': 9.39614,
#    'Cv_molar_std': 0.10830059},
#   {'id': 542,
#    'structure': 'qmof-cb9ea13.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.9325264586,
#    'Cv_gravimetric_std': 0.0074377848,
#    'Cv_molar_mean': 9.629736,
#    'Cv_molar_std': 0.07680618},
#   {'id': 543,
#    'structure': 'qmof-cb9ea13.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.2534111995,
#    'Cv_gravimetric_std': 0.0052151232,
#    'Cv_molar_mean': 12.943352,
#    'Cv_molar_std': 0.053854067},
#   {'id': 544,
#    'structure': 'str_m4_o1_o4_acs_sym.68.cif',
#    'temperature_K': 288.15,
#    'temperature_C': 15.0,
#    'Cv_gravimetric_mean': 0.8410297284,
#    'Cv_gravimetric_std': 0.0053548197,
#    'Cv_molar_mean': 10.772977,
#    'Cv_molar_std': 0.06859131},
#   {'id': 545,
#    'structure': 'str_m4_o1_o4_acs_sym.68.cif',
#    'temperature_K': 300.0,
#    'temperature_C': 26.85,
#    'Cv_gravimetric_mean': 0.861937753,
#    'Cv_gravimetric_std': 0.0064738799,
#    'Cv_molar_mean': 11.040793,
#    'Cv_molar_std': 0.0829258},
#   {'id': 546,
#    'structure': 'str_m4_o1_o4_acs_sym.68.cif',
#    'temperature_K': 423.15,
#    'temperature_C': 150.0,
#    'Cv_gravimetric_mean': 1.0974676407,
#    'Cv_gravimetric_std': 0.0024133121,
#    'Cv_molar_mean': 14.057759,
#    'Cv_molar_std': 0.030912587}]}

# %%
df = pd.read_csv('../../AutoPrism/results/isotherm_H2.csv')
api.update_isotherm_h2(df)
# Out:
# {'created_count': 0,
#  'updated_count': 33,
#  'error_count': 0,
#  'created_records': [],
#  'updated_records': [{'id': 34,
#    'structure': 'RSM1045.cif',
#    'md5': 'b0cd85b58291c495ba191996ae70fd9b',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': 'd041cce19d10cded485f2f42588a7d9a2de9a0a6',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 5.0,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.407514,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 14.4259956,
#    'absolute_loading_mol_kg': 0.5405547,
#    'avg_number_of_molecules': 18.75245,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -6.792868,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -9.5759264999},
#   {'id': 35,
#    'structure': 'RSM1045.cif',
#    'md5': 'b0cd85b58291c495ba191996ae70fd9b',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '46177ba2bbcd7e598fbae3b2e92ef4a992302a87',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 30.0,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.407514,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 14.4259956,
#    'absolute_loading_mol_kg': 2.643036,
#    'avg_number_of_molecules': 91.6899,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -6.915864,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -9.6989224999},
#   {'id': 36,
#    'structure': 'RSM1045.cif',
#    'md5': 'b0cd85b58291c495ba191996ae70fd9b',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '4609dc6e9ccf7035b6d79b9e923aa5fae12b836c',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 50.0,
#    'framework_charge_origin': 'CIF_File',
#    'framework_cif_has_atom_site_charge': True,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.407514,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 14.4259956,
#    'absolute_loading_mol_kg': 3.846053,
#    'avg_number_of_molecules': 133.4239,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -6.973504,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -9.7565624999},
#   {'id': 37,
#    'structure': 'koslub_P1_fixed.cif',
#    'md5': 'ceed6438ea2618a6ec762a0bc806a8b6',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': 'd041cce19d10cded485f2f42588a7d9a2de9a0a6',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 5.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.491646,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 17.4042684,
#    'absolute_loading_mol_kg': 0.4180808,
#    'avg_number_of_molecules': 18.75265,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -5.336685,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -8.1197434999},
#   {'id': 38,
#    'structure': 'koslub_P1_fixed.cif',
#    'md5': 'ceed6438ea2618a6ec762a0bc806a8b6',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '46177ba2bbcd7e598fbae3b2e92ef4a992302a87',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 30.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.491646,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 17.4042684,
#    'absolute_loading_mol_kg': 2.215609,
#    'avg_number_of_molecules': 99.3792,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -5.356966,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -8.1400244999},
#   {'id': 39,
#    'structure': 'koslub_P1_fixed.cif',
#    'md5': 'ceed6438ea2618a6ec762a0bc806a8b6',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '4609dc6e9ccf7035b6d79b9e923aa5fae12b836c',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 50.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.491646,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 17.4042684,
#    'absolute_loading_mol_kg': 3.390615,
#    'avg_number_of_molecules': 152.0831,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -5.4329,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -8.2159584999},
#   {'id': 40,
#    'structure': 'qmof-0a464a7.cif',
#    'md5': '84efd9f132bedab343ff77e2437329a0',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': 'd041cce19d10cded485f2f42588a7d9a2de9a0a6',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 5.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.669413,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 23.6972202,
#    'absolute_loading_mol_kg': 0.9973536,
#    'avg_number_of_molecules': 17.031,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -7.282536,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -10.0655944999},
#   {'id': 41,
#    'structure': 'qmof-0a464a7.cif',
#    'md5': '84efd9f132bedab343ff77e2437329a0',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '46177ba2bbcd7e598fbae3b2e92ef4a992302a87',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 30.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.669413,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 23.6972202,
#    'absolute_loading_mol_kg': 4.481427,
#    'avg_number_of_molecules': 76.5257,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -6.799204,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -9.5822624999},
#   {'id': 42,
#    'structure': 'qmof-0a464a7.cif',
#    'md5': '84efd9f132bedab343ff77e2437329a0',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '4609dc6e9ccf7035b6d79b9e923aa5fae12b836c',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 50.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.669413,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 23.6972202,
#    'absolute_loading_mol_kg': 6.44618,
#    'avg_number_of_molecules': 110.0762,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -6.657303,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -9.4403614999},
#   {'id': 43,
#    'structure': 'qmof-1da6c76.cif',
#    'md5': 'b1dd762e1662df50a8c893131ae9cb11',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': 'd041cce19d10cded485f2f42588a7d9a2de9a0a6',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 5.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 2.52665,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 89.44341,
#    'absolute_loading_mol_kg': 1.143754,
#    'avg_number_of_molecules': 8.9258,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -3.598754,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -6.3818124999},
#   {'id': 44,
#    'structure': 'qmof-1da6c76.cif',
#    'md5': 'b1dd762e1662df50a8c893131ae9cb11',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '46177ba2bbcd7e598fbae3b2e92ef4a992302a87',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 30.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 2.52665,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 89.44341,
#    'absolute_loading_mol_kg': 6.409495,
#    'avg_number_of_molecules': 50.0194,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -3.616653,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -6.3997114999},
#   {'id': 45,
#    'structure': 'qmof-1da6c76.cif',
#    'md5': 'b1dd762e1662df50a8c893131ae9cb11',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '4609dc6e9ccf7035b6d79b9e923aa5fae12b836c',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 50.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 2.52665,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 89.44341,
#    'absolute_loading_mol_kg': 10.31323,
#    'avg_number_of_molecules': 80.484,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -3.645609,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -6.4286674999},
#   {'id': 46,
#    'structure': 'qmof-3beea42.cif',
#    'md5': 'd151c224aed78554fad428c25f1b3124',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': 'd041cce19d10cded485f2f42588a7d9a2de9a0a6',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 5.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.755691,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 26.7514614,
#    'absolute_loading_mol_kg': 0.9216785,
#    'avg_number_of_molecules': 15.46635,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -6.546796,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -9.3298544999},
#   {'id': 47,
#    'structure': 'qmof-3beea42.cif',
#    'md5': 'd151c224aed78554fad428c25f1b3124',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '46177ba2bbcd7e598fbae3b2e92ef4a992302a87',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 30.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.755691,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 26.7514614,
#    'absolute_loading_mol_kg': 4.559753,
#    'avg_number_of_molecules': 76.51555,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -6.644323,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -9.4273814999},
#   {'id': 48,
#    'structure': 'qmof-3beea42.cif',
#    'md5': 'd151c224aed78554fad428c25f1b3124',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '4609dc6e9ccf7035b6d79b9e923aa5fae12b836c',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 50.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.755691,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 26.7514614,
#    'absolute_loading_mol_kg': 6.782253,
#    'avg_number_of_molecules': 113.8105,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -6.655317,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -9.4383754999},
#   {'id': 49,
#    'structure': 'qmof-798e431.cif',
#    'md5': '853c87c73a38c205d09c91658fda10f8',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': 'd041cce19d10cded485f2f42588a7d9a2de9a0a6',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 5.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 2.70945,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 95.91453,
#    'absolute_loading_mol_kg': 1.188169,
#    'avg_number_of_molecules': 16.7569,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -3.508371,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -6.2914294999},
#   {'id': 50,
#    'structure': 'qmof-798e431.cif',
#    'md5': '853c87c73a38c205d09c91658fda10f8',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '46177ba2bbcd7e598fbae3b2e92ef4a992302a87',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 30.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 2.70945,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 95.91453,
#    'absolute_loading_mol_kg': 6.756798,
#    'avg_number_of_molecules': 95.292,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -3.489736,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -6.2727944999},
#   {'id': 51,
#    'structure': 'qmof-798e431.cif',
#    'md5': '853c87c73a38c205d09c91658fda10f8',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '4609dc6e9ccf7035b6d79b9e923aa5fae12b836c',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 50.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 2.70945,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 95.91453,
#    'absolute_loading_mol_kg': 10.88375,
#    'avg_number_of_molecules': 153.495,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -3.521238,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -6.3042964999},
#   {'id': 52,
#    'structure': 'qmof-7c567fa.cif',
#    'md5': '650007ea35848e188b1dc4c34efe99ab',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': 'd041cce19d10cded485f2f42588a7d9a2de9a0a6',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 5.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 2.38533,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 84.440682,
#    'absolute_loading_mol_kg': 1.091537,
#    'avg_number_of_molecules': 11.14755,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -3.598592,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -6.3816504999},
#   {'id': 53,
#    'structure': 'qmof-7c567fa.cif',
#    'md5': '650007ea35848e188b1dc4c34efe99ab',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '46177ba2bbcd7e598fbae3b2e92ef4a992302a87',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 30.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 2.38533,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 84.440682,
#    'absolute_loading_mol_kg': 6.133979,
#    'avg_number_of_molecules': 62.64455,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -3.670001,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -6.4530594999},
#   {'id': 54,
#    'structure': 'qmof-7c567fa.cif',
#    'md5': '650007ea35848e188b1dc4c34efe99ab',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '4609dc6e9ccf7035b6d79b9e923aa5fae12b836c',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 50.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 2.38533,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 84.440682,
#    'absolute_loading_mol_kg': 9.937685,
#    'avg_number_of_molecules': 101.4907,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -3.700268,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -6.4833264999},
#   {'id': 55,
#    'structure': 'qmof-97d5d0e.cif',
#    'md5': 'c1e3adaea2ae0e27eb3fe8cdd2b39ac6',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': 'd041cce19d10cded485f2f42588a7d9a2de9a0a6',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 5.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 3.61109,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 127.832586,
#    'absolute_loading_mol_kg': 1.498068,
#    'avg_number_of_molecules': 7.21325,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -3.294942,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -6.0780004999},
#   {'id': 56,
#    'structure': 'qmof-97d5d0e.cif',
#    'md5': 'c1e3adaea2ae0e27eb3fe8cdd2b39ac6',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '46177ba2bbcd7e598fbae3b2e92ef4a992302a87',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 30.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 3.61109,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 127.832586,
#    'absolute_loading_mol_kg': 8.393919,
#    'avg_number_of_molecules': 40.417,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -3.259199,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -6.0422574999},
#   {'id': 57,
#    'structure': 'qmof-97d5d0e.cif',
#    'md5': 'c1e3adaea2ae0e27eb3fe8cdd2b39ac6',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '4609dc6e9ccf7035b6d79b9e923aa5fae12b836c',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 50.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 3.61109,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 127.832586,
#    'absolute_loading_mol_kg': 13.59994,
#    'avg_number_of_molecules': 65.48415,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -3.282677,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -6.0657354999},
#   {'id': 58,
#    'structure': 'qmof-9fd01d7.cif',
#    'md5': 'a07d8cb4f99171f7ce36244c3f8669cd',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': 'd041cce19d10cded485f2f42588a7d9a2de9a0a6',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 5.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 2.53441,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 89.718114,
#    'absolute_loading_mol_kg': 1.178731,
#    'avg_number_of_molecules': 8.5293,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -3.668509,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -6.4515674999},
#   {'id': 59,
#    'structure': 'qmof-9fd01d7.cif',
#    'md5': 'a07d8cb4f99171f7ce36244c3f8669cd',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '46177ba2bbcd7e598fbae3b2e92ef4a992302a87',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 30.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 2.53441,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 89.718114,
#    'absolute_loading_mol_kg': 6.524648,
#    'avg_number_of_molecules': 47.21235,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -3.666002,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -6.4490604999},
#   {'id': 60,
#    'structure': 'qmof-9fd01d7.cif',
#    'md5': 'a07d8cb4f99171f7ce36244c3f8669cd',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '4609dc6e9ccf7035b6d79b9e923aa5fae12b836c',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 50.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 2.53441,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 89.718114,
#    'absolute_loading_mol_kg': 10.48504,
#    'avg_number_of_molecules': 75.86975,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -3.661207,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -6.4442654999},
#   {'id': 61,
#    'structure': 'qmof-b4192d1.cif',
#    'md5': 'e765fd21c2e55927a13b44ad71f14688',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': 'd041cce19d10cded485f2f42588a7d9a2de9a0a6',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 5.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.687412,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 24.3343848,
#    'absolute_loading_mol_kg': 0.8929435,
#    'avg_number_of_molecules': 10.23915,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -6.660971,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -9.4440294999},
#   {'id': 62,
#    'structure': 'qmof-b4192d1.cif',
#    'md5': 'e765fd21c2e55927a13b44ad71f14688',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '46177ba2bbcd7e598fbae3b2e92ef4a992302a87',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 30.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.687412,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 24.3343848,
#    'absolute_loading_mol_kg': 4.237573,
#    'avg_number_of_molecules': 48.59115,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -6.619643,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -9.4027014999},
#   {'id': 63,
#    'structure': 'qmof-b4192d1.cif',
#    'md5': 'e765fd21c2e55927a13b44ad71f14688',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '4609dc6e9ccf7035b6d79b9e923aa5fae12b836c',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 50.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.687412,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 24.3343848,
#    'absolute_loading_mol_kg': 6.149922,
#    'avg_number_of_molecules': 70.51955,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -6.615419,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -9.3984774999},
#   {'id': 64,
#    'structure': 'qmof-cb9ea13.cif',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': 'd041cce19d10cded485f2f42588a7d9a2de9a0a6',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 5.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.656311,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 23.2334094,
#    'absolute_loading_mol_kg': 0.8662795,
#    'avg_number_of_molecules': 14.3132,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -6.461225,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -9.2442834999},
#   {'id': 65,
#    'structure': 'qmof-cb9ea13.cif',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '46177ba2bbcd7e598fbae3b2e92ef4a992302a87',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 30.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.656311,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 23.2334094,
#    'absolute_loading_mol_kg': 4.206781,
#    'avg_number_of_molecules': 69.507,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -6.569661,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -9.3527194999},
#   {'id': 66,
#    'structure': 'qmof-cb9ea13.cif',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'isotherm_id': 'h2_lowp_minus50C',
#    'isotherm': 'H2 low-pressure (-50 °C): 5/30/50 bar',
#    'config_hash': '4609dc6e9ccf7035b6d79b9e923aa5fae12b836c',
#    'mode': 'gcmc',
#    'component': 'H2',
#    'temperature_K': 223.15,
#    'pressure_bar': 50.0,
#    'framework_charge_origin': 'ChargeEquilibration',
#    'framework_cif_has_atom_site_charge': False,
#    'charge_method': 'Ewald',
#    'ewald_precision': None,
#    'component_is_charged': False,
#    'component_charge_origin': 'force_field.json:PseudoAtoms',
#    'poav_cm3_per_g': 0.656311,
#    'molsatdens_mol_L': 35.4,
#    'estimated_saturation_loading_mol_kg': 23.2334094,
#    'absolute_loading_mol_kg': 6.169476,
#    'avg_number_of_molecules': 101.9359,
#    'henry_mol_kg_Pa': None,
#    'henry_unit': None,
#    'enthalpy_of_adsorption_kJ_mol': -6.604067,
#    'ideal_gas_energy_kJ_mol': 2.7830584999,
#    'heat_of_adsorption_kJ_mol': -9.3871254999}]}

# %%
df = pd.read_csv('../../AutoPrism/results/mofchecker.csv')
api.update_mofchecker(df)
# Out:
# {'created_count': 0,
#  'updated_count': 91,
#  'error_count': 0,
#  'created_records': [],
#  'updated_records': [{'id': 92,
#    'structure': '05000N2_ddec.cif',
#    'md5': '38fa1a4a57d75602d1f962e5be326796',
#    'is_mof': False,
#    'MOFQ': False,
#    'mofq_reason': 'fast_non_mof:no_metal_atoms',
#    'mofchecker_blob': None,
#    'mofchecker_log': None,
#    'mofchecker_updated_at': '2026-01-20T18:31:37Z'},
#   {'id': 93,
#    'structure': '05001N2_ddec.cif',
#    'md5': 'd09dd23c55c78b140591d8566883ebbc',
#    'is_mof': False,
#    'MOFQ': False,
#    'mofq_reason': 'fast_non_mof:no_metal_atoms',
#    'mofchecker_blob': None,
#    'mofchecker_log': None,
#    'mofchecker_updated_at': '2026-01-20T18:31:37Z'},
#   {'id': 94,
#    'structure': '07000N2_ddec.cif',
#    'md5': '17ca1f693001d5f4b62e9215cd6379eb',
#    'is_mof': False,
#    'MOFQ': False,
#    'mofq_reason': 'fast_non_mof:no_metal_atoms',
#    'mofchecker_blob': None,
#    'mofchecker_log': None,
#    'mofchecker_updated_at': '2026-01-20T18:31:37Z'},
#   {'id': 95,
#    'structure': '07001N2_ddec.cif',
#    'md5': '07efdb27d3ccf4e78e03da044906f917',
#    'is_mof': False,
#    'MOFQ': False,
#    'mofq_reason': 'fast_non_mof:no_metal_atoms',
#    'mofchecker_blob': None,
#    'mofchecker_log': None,
#    'mofchecker_updated_at': '2026-01-20T18:31:37Z'},
#   {'id': 96,
#    'structure': '08000N3_ddec.cif',
#    'md5': '1da8a7bc1aa56632455c6c2b643c2d7c',
#    'is_mof': False,
#    'MOFQ': False,
#    'mofq_reason': 'fast_non_mof:no_metal_atoms',
#    'mofchecker_blob': None,
#    'mofchecker_log': None,
#    'mofchecker_updated_at': '2026-01-20T18:31:37Z'},
#   {'id': 97,
#    'structure': '15070N2_ddec.cif',
#    'md5': 'c5c5b4ebd33465b24ded58a5d4f49b24',
#    'is_mof': False,
#    'MOFQ': False,
#    'mofq_reason': 'fast_non_mof:no_metal_atoms',
#    'mofchecker_blob': None,
#    'mofchecker_log': None,
#    'mofchecker_updated_at': '2026-01-20T18:31:37Z'},
#   {'id': 98,
#    'structure': '16057N2_ddec.cif',
#    'md5': '6202432f901e6b6d68c4dd3bc2ce866c',
#    'is_mof': False,
#    'MOFQ': False,
#    'mofq_reason': 'fast_non_mof:no_metal_atoms',
#    'mofchecker_blob': None,
#    'mofchecker_log': None,
#    'mofchecker_updated_at': '2026-01-20T18:31:37Z'},
#   {'id': 99,
#    'structure': '17150N2_ddec.cif',
#    'md5': 'dcc908a9605f5f513d6a7a1d220b25ef',
#    'is_mof': False,
#    'MOFQ': False,
#    'mofq_reason': 'fast_non_mof:no_metal_atoms',
#    'mofchecker_blob': None,
#    'mofchecker_log': None,
#    'mofchecker_updated_at': '2026-01-20T18:31:37Z'},
#   {'id': 100,
#    'structure': '19020N3_ddec.cif',
#    'md5': '9d1d4333c36c84121f85fd95f7112c6e',
#    'is_mof': False,
#    'MOFQ': False,
#    'mofq_reason': 'fast_non_mof:no_metal_atoms',
#    'mofchecker_blob': None,
#    'mofchecker_log': None,
#    'mofchecker_updated_at': '2026-01-20T18:31:37Z'},
#   {'id': 101,
#    'structure': '20051N2_ddec.cif',
#    'md5': '7409057b99b5ac68066d923ded4ca2a8',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '7409057b99b5ac68066d923ded4ca2a8_mofchecker.json',
#    'mofchecker_log': 'logs/7409057b99b5ac68066d923ded4ca2a8_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:31:44Z'},
#   {'id': 102,
#    'structure': '20590N2_ddec.cif',
#    'md5': '735702b3d8c787aa19784f8b53bb6c9e',
#    'is_mof': False,
#    'MOFQ': False,
#    'mofq_reason': 'fast_non_mof:no_metal_atoms',
#    'mofchecker_blob': None,
#    'mofchecker_log': None,
#    'mofchecker_updated_at': '2026-01-20T18:31:44Z'},
#   {'id': 103,
#    'structure': '21030N2_ddec.cif',
#    'md5': '7366b13430080588504f0bf8bd2a387f',
#    'is_mof': False,
#    'MOFQ': False,
#    'mofq_reason': 'fast_non_mof:no_metal_atoms',
#    'mofchecker_blob': None,
#    'mofchecker_log': None,
#    'mofchecker_updated_at': '2026-01-20T18:31:44Z'},
#   {'id': 104,
#    'structure': '22108N2_ddec.cif',
#    'md5': 'b658efcf311744888b772d09151f8e92',
#    'is_mof': False,
#    'MOFQ': False,
#    'mofq_reason': 'fast_non_mof:no_metal_atoms',
#    'mofchecker_blob': None,
#    'mofchecker_log': None,
#    'mofchecker_updated_at': '2026-01-20T18:31:44Z'},
#   {'id': 105,
#    'structure': '22221N2_ddec.cif',
#    'md5': '544145e69898ec2ce922aaf64b32bafa',
#    'is_mof': False,
#    'MOFQ': False,
#    'mofq_reason': 'fast_non_mof:no_metal_atoms',
#    'mofchecker_blob': None,
#    'mofchecker_log': None,
#    'mofchecker_updated_at': '2026-01-20T18:31:44Z'},
#   {'id': 106,
#    'structure': '22551N2_ddec.cif',
#    'md5': 'd3e2466eb9415ff422be4bea2e1a074a',
#    'is_mof': False,
#    'MOFQ': False,
#    'mofq_reason': 'fast_non_mof:no_metal_atoms',
#    'mofchecker_blob': None,
#    'mofchecker_log': None,
#    'mofchecker_updated_at': '2026-01-20T18:31:44Z'},
#   {'id': 107,
#    'structure': 'ASEJOZ.cif',
#    'md5': 'cc5178b74a53bf9ec963c6df0fde4c6e',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'cc5178b74a53bf9ec963c6df0fde4c6e_mofchecker.json',
#    'mofchecker_log': 'logs/cc5178b74a53bf9ec963c6df0fde4c6e_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:31:49Z'},
#   {'id': 108,
#    'structure': 'ASEJOZ01_clean.cif',
#    'md5': '08759f403a58b6b0a11029bc8cb2551d',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '08759f403a58b6b0a11029bc8cb2551d_mofchecker.json',
#    'mofchecker_log': 'logs/08759f403a58b6b0a11029bc8cb2551d_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:31:53Z'},
#   {'id': 109,
#    'structure': 'AWASAU_clean.cif',
#    'md5': '7a1f8ff0a9b0555ff9a97c5895ae30a2',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '7a1f8ff0a9b0555ff9a97c5895ae30a2_mofchecker.json',
#    'mofchecker_log': 'logs/7a1f8ff0a9b0555ff9a97c5895ae30a2_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:31:58Z'},
#   {'id': 110,
#    'structure': 'AWASOI_clean.cif',
#    'md5': '5dbfdd322670ead4c997b84b2f6e4997',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '5dbfdd322670ead4c997b84b2f6e4997_mofchecker.json',
#    'mofchecker_log': 'logs/5dbfdd322670ead4c997b84b2f6e4997_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:32:06Z'},
#   {'id': 111,
#    'structure': 'BETGUE_clean.cif',
#    'md5': 'a1dd3ef62f00e5c1251fa7873d16f977',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'a1dd3ef62f00e5c1251fa7873d16f977_mofchecker.json',
#    'mofchecker_log': 'logs/a1dd3ef62f00e5c1251fa7873d16f977_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:32:11Z'},
#   {'id': 112,
#    'structure': 'CANRUG_clean.cif',
#    'md5': '24c4b2e063d1dc866baa37b97750c927',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '24c4b2e063d1dc866baa37b97750c927_mofchecker.json',
#    'mofchecker_log': 'logs/24c4b2e063d1dc866baa37b97750c927_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:32:17Z'},
#   {'id': 113,
#    'structure': 'COCNAL_clean.cif',
#    'md5': '6bcb6439e8f347913711b02170ec714f',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '6bcb6439e8f347913711b02170ec714f_mofchecker.json',
#    'mofchecker_log': 'logs/6bcb6439e8f347913711b02170ec714f_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:32:27Z'},
#   {'id': 114,
#    'structure': 'COYTIU_clean.cif',
#    'md5': '03f7703dafeb0be983c3a69dd7c4a6f3',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '03f7703dafeb0be983c3a69dd7c4a6f3_mofchecker.json',
#    'mofchecker_log': 'logs/03f7703dafeb0be983c3a69dd7c4a6f3_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:32:31Z'},
#   {'id': 115,
#    'structure': 'COYTOA_clean.cif',
#    'md5': '9e1ff3085eb6946df2cf2293741bbf6f',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '9e1ff3085eb6946df2cf2293741bbf6f_mofchecker.json',
#    'mofchecker_log': 'logs/9e1ff3085eb6946df2cf2293741bbf6f_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:32:36Z'},
#   {'id': 116,
#    'structure': 'DATPIY_clean.cif',
#    'md5': '30ff4e93f130f8fa5e34bdab55e50f91',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '30ff4e93f130f8fa5e34bdab55e50f91_mofchecker.json',
#    'mofchecker_log': 'logs/30ff4e93f130f8fa5e34bdab55e50f91_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:32:41Z'},
#   {'id': 117,
#    'structure': 'DOMDAL_clean.cif',
#    'md5': '1c8df5a6518a25c482f264f3bedd2162',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '1c8df5a6518a25c482f264f3bedd2162_mofchecker.json',
#    'mofchecker_log': 'logs/1c8df5a6518a25c482f264f3bedd2162_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:32:47Z'},
#   {'id': 118,
#    'structure': 'DOQGUM_clean.cif',
#    'md5': '6ea3e5b31fb913bef56fa95cd0b3277b',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '6ea3e5b31fb913bef56fa95cd0b3277b_mofchecker.json',
#    'mofchecker_log': 'logs/6ea3e5b31fb913bef56fa95cd0b3277b_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:32:51Z'},
#   {'id': 119,
#    'structure': 'DOQHIB_clean.cif',
#    'md5': 'c08661d58bb7f0074ad15203cad215dd',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'c08661d58bb7f0074ad15203cad215dd_mofchecker.json',
#    'mofchecker_log': 'logs/c08661d58bb7f0074ad15203cad215dd_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:32:55Z'},
#   {'id': 120,
#    'structure': 'ELILER_clean.cif',
#    'md5': '24f47e65b0de4fd3c8f0453923375334',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '24f47e65b0de4fd3c8f0453923375334_mofchecker.json',
#    'mofchecker_log': 'logs/24f47e65b0de4fd3c8f0453923375334_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:33:00Z'},
#   {'id': 121,
#    'structure': 'EXIBUI_clean.cif',
#    'md5': '912a0bd0e64ffa605348c360f16175e0',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '912a0bd0e64ffa605348c360f16175e0_mofchecker.json',
#    'mofchecker_log': 'logs/912a0bd0e64ffa605348c360f16175e0_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:33:04Z'},
#   {'id': 122,
#    'structure': 'GADFAV_clean.cif',
#    'md5': '30d7005e525010e1056ae50572327df1',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '30d7005e525010e1056ae50572327df1_mofchecker.json',
#    'mofchecker_log': 'logs/30d7005e525010e1056ae50572327df1_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:33:08Z'},
#   {'id': 123,
#    'structure': 'GAJYUN_clean.cif',
#    'md5': '51c86bd205edc3454842944b88b45fc7',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '51c86bd205edc3454842944b88b45fc7_mofchecker.json',
#    'mofchecker_log': 'logs/51c86bd205edc3454842944b88b45fc7_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:33:12Z'},
#   {'id': 124,
#    'structure': 'GAJZEY_clean.cif',
#    'md5': '3573f96507bc83310121a7ee0f14ea65',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '3573f96507bc83310121a7ee0f14ea65_mofchecker.json',
#    'mofchecker_log': 'logs/3573f96507bc83310121a7ee0f14ea65_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:33:16Z'},
#   {'id': 125,
#    'structure': 'HOWROC_clean.cif',
#    'md5': 'eac13e2d4e1d7be8f038dd0738f25f57',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'eac13e2d4e1d7be8f038dd0738f25f57_mofchecker.json',
#    'mofchecker_log': 'logs/eac13e2d4e1d7be8f038dd0738f25f57_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:33:23Z'},
#   {'id': 126,
#    'structure': 'KIBDEF_clean.cif',
#    'md5': 'b4345b687f3113480c5b3792a61aadaa',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'b4345b687f3113480c5b3792a61aadaa_mofchecker.json',
#    'mofchecker_log': 'logs/b4345b687f3113480c5b3792a61aadaa_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:33:28Z'},
#   {'id': 127,
#    'structure': 'KIBDIJ_clean.cif',
#    'md5': '8741ed541698c26e1ca962178d146e99',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '8741ed541698c26e1ca962178d146e99_mofchecker.json',
#    'mofchecker_log': 'logs/8741ed541698c26e1ca962178d146e99_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:33:32Z'},
#   {'id': 128,
#    'structure': 'LADWAR_clean.cif',
#    'md5': '23d096b6bcafc6dac0cbfde64cd6790f',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '23d096b6bcafc6dac0cbfde64cd6790f_mofchecker.json',
#    'mofchecker_log': 'logs/23d096b6bcafc6dac0cbfde64cd6790f_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:33:36Z'},
#   {'id': 129,
#    'structure': 'LAGNAK_clean.cif',
#    'md5': '5fb9d99008a2e440f74f463ac138177d',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '5fb9d99008a2e440f74f463ac138177d_mofchecker.json',
#    'mofchecker_log': 'logs/5fb9d99008a2e440f74f463ac138177d_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:33:40Z'},
#   {'id': 130,
#    'structure': 'LAGQER_clean.cif',
#    'md5': '623d60bfe0ef0ae4044430c63519110f',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '623d60bfe0ef0ae4044430c63519110f_mofchecker.json',
#    'mofchecker_log': 'logs/623d60bfe0ef0ae4044430c63519110f_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:33:44Z'},
#   {'id': 131,
#    'structure': 'MEHMET_clean.cif',
#    'md5': '1ff62550d139facd6dca5644b47d5eb2',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '1ff62550d139facd6dca5644b47d5eb2_mofchecker.json',
#    'mofchecker_log': 'logs/1ff62550d139facd6dca5644b47d5eb2_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:33:52Z'},
#   {'id': 132,
#    'structure': 'MIFSAX_clean.cif',
#    'md5': 'e2364690df886102f38d5be84d520ff0',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'e2364690df886102f38d5be84d520ff0_mofchecker.json',
#    'mofchecker_log': 'logs/e2364690df886102f38d5be84d520ff0_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:34:02Z'},
#   {'id': 133,
#    'structure': 'MOLRIP_clean.cif',
#    'md5': 'dab9113849bf5da546e580df8c374671',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'dab9113849bf5da546e580df8c374671_mofchecker.json',
#    'mofchecker_log': 'logs/dab9113849bf5da546e580df8c374671_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:34:07Z'},
#   {'id': 134,
#    'structure': 'MOTMAK.cif',
#    'md5': 'b701450ed7c226620510e27245674b13',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'b701450ed7c226620510e27245674b13_mofchecker.json',
#    'mofchecker_log': 'logs/b701450ed7c226620510e27245674b13_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:34:12Z'},
#   {'id': 135,
#    'structure': 'MUGXIX_clean.cif',
#    'md5': 'da58fd555696cddd4768871940015236',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'da58fd555696cddd4768871940015236_mofchecker.json',
#    'mofchecker_log': 'logs/da58fd555696cddd4768871940015236_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:34:17Z'},
#   {'id': 136,
#    'structure': 'NARPOO_clean.cif',
#    'md5': 'bdd4ffa4c3fdf1503ee89ca981699692',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'bdd4ffa4c3fdf1503ee89ca981699692_mofchecker.json',
#    'mofchecker_log': 'logs/bdd4ffa4c3fdf1503ee89ca981699692_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:34:21Z'},
#   {'id': 137,
#    'structure': 'NEPWIQ_clean.cif',
#    'md5': 'c916cda073c1c25037f748a836caad02',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'c916cda073c1c25037f748a836caad02_mofchecker.json',
#    'mofchecker_log': 'logs/c916cda073c1c25037f748a836caad02_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:34:25Z'},
#   {'id': 138,
#    'structure': 'NOCLUN_clean.cif',
#    'md5': '6bb3f63ed642f5c7f7d43e3492fbc10b',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '6bb3f63ed642f5c7f7d43e3492fbc10b_mofchecker.json',
#    'mofchecker_log': 'logs/6bb3f63ed642f5c7f7d43e3492fbc10b_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:34:29Z'},
#   {'id': 139,
#    'structure': 'NOCYUB_clean.cif',
#    'md5': '4ecc397155accf02154f90541ddb466c',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '4ecc397155accf02154f90541ddb466c_mofchecker.json',
#    'mofchecker_log': 'logs/4ecc397155accf02154f90541ddb466c_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:34:34Z'},
#   {'id': 140,
#    'structure': 'NaCl_P1.cif',
#    'md5': '8bff40507b0e9a9fbda85a76db389288',
#    'is_mof': True,
#    'MOFQ': False,
#    'mofq_reason': 'check_failed:has_carbon',
#    'mofchecker_blob': '8bff40507b0e9a9fbda85a76db389288_mofchecker.json',
#    'mofchecker_log': 'logs/8bff40507b0e9a9fbda85a76db389288_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:34:38Z'},
#   {'id': 141,
#    'structure': 'NbOFFIVE-1-Ni.cif',
#    'md5': '366d11663de616d0147c6a15a4c3cafb',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '366d11663de616d0147c6a15a4c3cafb_mofchecker.json',
#    'mofchecker_log': 'logs/366d11663de616d0147c6a15a4c3cafb_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:34:42Z'},
#   {'id': 142,
#    'structure': 'ODAJAG_clean.cif',
#    'md5': 'b22cd9d887260045cd811541a58d861f',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'b22cd9d887260045cd811541a58d861f_mofchecker.json',
#    'mofchecker_log': 'logs/b22cd9d887260045cd811541a58d861f_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:34:46Z'},
#   {'id': 143,
#    'structure': 'OSAVUA_clean.cif',
#    'md5': 'e7f1573744a1685c46ec96622cc28893',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'e7f1573744a1685c46ec96622cc28893_mofchecker.json',
#    'mofchecker_log': 'logs/e7f1573744a1685c46ec96622cc28893_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:34:50Z'},
#   {'id': 144,
#    'structure': 'OZAVES_clean.cif',
#    'md5': '7a6020b6410101514a97f35370bb6784',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '7a6020b6410101514a97f35370bb6784_mofchecker.json',
#    'mofchecker_log': 'logs/7a6020b6410101514a97f35370bb6784_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:34:54Z'},
#   {'id': 145,
#    'structure': 'PAMHES01_clean.cif',
#    'md5': '131cd977840473ff012c1402dc45d084',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '131cd977840473ff012c1402dc45d084_mofchecker.json',
#    'mofchecker_log': 'logs/131cd977840473ff012c1402dc45d084_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:34:59Z'},
#   {'id': 146,
#    'structure': 'PEGPUO_clean.cif',
#    'md5': 'e6c3ffe36ee691fe3ba687e0666fa17b',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'e6c3ffe36ee691fe3ba687e0666fa17b_mofchecker.json',
#    'mofchecker_log': 'logs/e6c3ffe36ee691fe3ba687e0666fa17b_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:35:04Z'},
#   {'id': 147,
#    'structure': 'PEGQAV_clean.cif',
#    'md5': '7f1f9f0f649edd08c4f99154eb96f4d2',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '7f1f9f0f649edd08c4f99154eb96f4d2_mofchecker.json',
#    'mofchecker_log': 'logs/7f1f9f0f649edd08c4f99154eb96f4d2_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:35:09Z'},
#   {'id': 148,
#    'structure': 'QATRAG_clean.cif',
#    'md5': 'b175ebef08e023ae82ad1f0eacb23286',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'b175ebef08e023ae82ad1f0eacb23286_mofchecker.json',
#    'mofchecker_log': 'logs/b175ebef08e023ae82ad1f0eacb23286_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:35:13Z'},
#   {'id': 149,
#    'structure': 'RANNUS_clean.cif',
#    'md5': '233269f872b1a5d8d331a4a3cc4ec0cb',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '233269f872b1a5d8d331a4a3cc4ec0cb_mofchecker.json',
#    'mofchecker_log': 'logs/233269f872b1a5d8d331a4a3cc4ec0cb_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:35:18Z'},
#   {'id': 150,
#    'structure': 'RASXEP01_clean.cif',
#    'md5': '31104043524c0baee321686378928baf',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '31104043524c0baee321686378928baf_mofchecker.json',
#    'mofchecker_log': 'logs/31104043524c0baee321686378928baf_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:35:23Z'},
#   {'id': 151,
#    'structure': 'RSM0191.cif',
#    'md5': 'dd9fe78a600a5b0e34104ad61563738a',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'dd9fe78a600a5b0e34104ad61563738a_mofchecker.json',
#    'mofchecker_log': 'logs/dd9fe78a600a5b0e34104ad61563738a_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:35:27Z'},
#   {'id': 152,
#    'structure': 'RSM0462.cif',
#    'md5': 'e08706bc2eae344fdde66c9561ebc335',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'e08706bc2eae344fdde66c9561ebc335_mofchecker.json',
#    'mofchecker_log': 'logs/e08706bc2eae344fdde66c9561ebc335_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:35:31Z'},
#   {'id': 153,
#    'structure': 'RSM0661.cif',
#    'md5': 'b61534f94813d4b2b078dd10e14552dc',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'b61534f94813d4b2b078dd10e14552dc_mofchecker.json',
#    'mofchecker_log': 'logs/b61534f94813d4b2b078dd10e14552dc_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:35:36Z'},
#   {'id': 154,
#    'structure': 'RSM0663.cif',
#    'md5': '18b60c5267fc43bbffd8cc289259a856',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '18b60c5267fc43bbffd8cc289259a856_mofchecker.json',
#    'mofchecker_log': 'logs/18b60c5267fc43bbffd8cc289259a856_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:35:40Z'},
#   {'id': 155,
#    'structure': 'RSM0666.cif',
#    'md5': 'a5603c365f209215ce8c49a7f07f2aa0',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'a5603c365f209215ce8c49a7f07f2aa0_mofchecker.json',
#    'mofchecker_log': 'logs/a5603c365f209215ce8c49a7f07f2aa0_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:35:44Z'},
#   {'id': 156,
#    'structure': 'RSM0841.cif',
#    'md5': 'f3fb097973e9d4005e4003dac6f51eea',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'f3fb097973e9d4005e4003dac6f51eea_mofchecker.json',
#    'mofchecker_log': 'logs/f3fb097973e9d4005e4003dac6f51eea_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:35:48Z'},
#   {'id': 157,
#    'structure': 'RSM0850.cif',
#    'md5': '398c74b68b207c6d18e22e6f4426dcea',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '398c74b68b207c6d18e22e6f4426dcea_mofchecker.json',
#    'mofchecker_log': 'logs/398c74b68b207c6d18e22e6f4426dcea_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:35:53Z'},
#   {'id': 158,
#    'structure': 'RSM1045.cif',
#    'md5': 'b0cd85b58291c495ba191996ae70fd9b',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'b0cd85b58291c495ba191996ae70fd9b_mofchecker.json',
#    'mofchecker_log': 'logs/b0cd85b58291c495ba191996ae70fd9b_mofchecker.log',
#    'mofchecker_updated_at': '2026-02-05T13:29:56Z'},
#   {'id': 159,
#    'structure': 'RSM1361.cif',
#    'md5': '207ac63a4f7f84298aa1e31220c2a4fd',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '207ac63a4f7f84298aa1e31220c2a4fd_mofchecker.json',
#    'mofchecker_log': 'logs/207ac63a4f7f84298aa1e31220c2a4fd_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:35:57Z'},
#   {'id': 160,
#    'structure': 'RSM2114.cif',
#    'md5': 'cc547542b08caf0499ecac54363bffb4',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'cc547542b08caf0499ecac54363bffb4_mofchecker.json',
#    'mofchecker_log': 'logs/cc547542b08caf0499ecac54363bffb4_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:36:02Z'},
#   {'id': 161,
#    'structure': 'RUSWIN_clean.cif',
#    'md5': 'a138b03ca1d7a2e8faeeea71ed0523af',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'a138b03ca1d7a2e8faeeea71ed0523af_mofchecker.json',
#    'mofchecker_log': 'logs/a138b03ca1d7a2e8faeeea71ed0523af_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:36:07Z'},
#   {'id': 162,
#    'structure': 'UCUTIW_clean.cif',
#    'md5': '4555dac1ce6af93e6b5ca674a7045d4e',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '4555dac1ce6af93e6b5ca674a7045d4e_mofchecker.json',
#    'mofchecker_log': 'logs/4555dac1ce6af93e6b5ca674a7045d4e_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:36:11Z'},
#   {'id': 163,
#    'structure': 'UREVOE_clean.cif',
#    'md5': '3de3a9bc2e94ae58076c7a2845cf091c',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '3de3a9bc2e94ae58076c7a2845cf091c_mofchecker.json',
#    'mofchecker_log': 'logs/3de3a9bc2e94ae58076c7a2845cf091c_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:36:15Z'},
#   {'id': 164,
#    'structure': 'WEFZIS_clean.cif',
#    'md5': '77333f646bfcfa7ee90832a8a905572f',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '77333f646bfcfa7ee90832a8a905572f_mofchecker.json',
#    'mofchecker_log': 'logs/77333f646bfcfa7ee90832a8a905572f_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:36:19Z'},
#   {'id': 165,
#    'structure': 'WOHZAU_clean.cif',
#    'md5': 'a4758c20cc9cc7a517e5248ce0b2612d',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'a4758c20cc9cc7a517e5248ce0b2612d_mofchecker.json',
#    'mofchecker_log': 'logs/a4758c20cc9cc7a517e5248ce0b2612d_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:36:24Z'},
#   {'id': 166,
#    'structure': 'YITHOA01_clean.cif',
#    'md5': '37ceebaf5503288de644f9010a3b4209',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '37ceebaf5503288de644f9010a3b4209_mofchecker.json',
#    'mofchecker_log': 'logs/37ceebaf5503288de644f9010a3b4209_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:36:28Z'},
#   {'id': 167,
#    'structure': 'YOCSEQ_clean.cif',
#    'md5': '8fc960434eeaf288e45dde5074ccfc22',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '8fc960434eeaf288e45dde5074ccfc22_mofchecker.json',
#    'mofchecker_log': 'logs/8fc960434eeaf288e45dde5074ccfc22_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:36:31Z'},
#   {'id': 168,
#    'structure': 'ZEZPAX01_clean.cif',
#    'md5': 'cf7d3232c62fbe86b697e39a9466a397',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'cf7d3232c62fbe86b697e39a9466a397_mofchecker.json',
#    'mofchecker_log': 'logs/cf7d3232c62fbe86b697e39a9466a397_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:36:36Z'},
#   {'id': 169,
#    'structure': 'ZEZPOL_clean.cif',
#    'md5': '41b140c54d18db121cd6a48477ad7dde',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '41b140c54d18db121cd6a48477ad7dde_mofchecker.json',
#    'mofchecker_log': 'logs/41b140c54d18db121cd6a48477ad7dde_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:36:40Z'},
#   {'id': 170,
#    'structure': 'cau10-nh2.cif',
#    'md5': '740f4e67d45c412b633887c949804dbe',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '740f4e67d45c412b633887c949804dbe_mofchecker.json',
#    'mofchecker_log': 'logs/740f4e67d45c412b633887c949804dbe_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:36:46Z'},
#   {'id': 171,
#    'structure': 'koslub_P1_fixed.cif',
#    'md5': 'ceed6438ea2618a6ec762a0bc806a8b6',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'ceed6438ea2618a6ec762a0bc806a8b6_mofchecker.json',
#    'mofchecker_log': 'logs/ceed6438ea2618a6ec762a0bc806a8b6_mofchecker.log',
#    'mofchecker_updated_at': '2026-02-05T13:30:00Z'},
#   {'id': 172,
#    'structure': 'qmof-02d74bc.cif',
#    'md5': '23663b642e905198be7e885675ae8c45',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '23663b642e905198be7e885675ae8c45_mofchecker.json',
#    'mofchecker_log': 'logs/23663b642e905198be7e885675ae8c45_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:36:50Z'},
#   {'id': 173,
#    'structure': 'qmof-0a464a7.cif',
#    'md5': '84efd9f132bedab343ff77e2437329a0',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '84efd9f132bedab343ff77e2437329a0_mofchecker.json',
#    'mofchecker_log': 'logs/84efd9f132bedab343ff77e2437329a0_mofchecker.log',
#    'mofchecker_updated_at': '2026-02-05T13:30:05Z'},
#   {'id': 174,
#    'structure': 'qmof-1da6c76.cif',
#    'md5': 'b1dd762e1662df50a8c893131ae9cb11',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'b1dd762e1662df50a8c893131ae9cb11_mofchecker.json',
#    'mofchecker_log': 'logs/b1dd762e1662df50a8c893131ae9cb11_mofchecker.log',
#    'mofchecker_updated_at': '2026-02-05T13:30:09Z'},
#   {'id': 175,
#    'structure': 'qmof-3beea42.cif',
#    'md5': 'd151c224aed78554fad428c25f1b3124',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'd151c224aed78554fad428c25f1b3124_mofchecker.json',
#    'mofchecker_log': 'logs/d151c224aed78554fad428c25f1b3124_mofchecker.log',
#    'mofchecker_updated_at': '2026-02-05T13:30:13Z'},
#   {'id': 176,
#    'structure': 'qmof-798e431.cif',
#    'md5': '853c87c73a38c205d09c91658fda10f8',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '853c87c73a38c205d09c91658fda10f8_mofchecker.json',
#    'mofchecker_log': 'logs/853c87c73a38c205d09c91658fda10f8_mofchecker.log',
#    'mofchecker_updated_at': '2026-02-05T13:30:18Z'},
#   {'id': 177,
#    'structure': 'qmof-7c567fa.cif',
#    'md5': '650007ea35848e188b1dc4c34efe99ab',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '650007ea35848e188b1dc4c34efe99ab_mofchecker.json',
#    'mofchecker_log': 'logs/650007ea35848e188b1dc4c34efe99ab_mofchecker.log',
#    'mofchecker_updated_at': '2026-02-05T13:30:23Z'},
#   {'id': 178,
#    'structure': 'qmof-97d5d0e.cif',
#    'md5': 'c1e3adaea2ae0e27eb3fe8cdd2b39ac6',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'c1e3adaea2ae0e27eb3fe8cdd2b39ac6_mofchecker.json',
#    'mofchecker_log': 'logs/c1e3adaea2ae0e27eb3fe8cdd2b39ac6_mofchecker.log',
#    'mofchecker_updated_at': '2026-02-05T13:30:27Z'},
#   {'id': 179,
#    'structure': 'qmof-9fd01d7.cif',
#    'md5': 'a07d8cb4f99171f7ce36244c3f8669cd',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'a07d8cb4f99171f7ce36244c3f8669cd_mofchecker.json',
#    'mofchecker_log': 'logs/a07d8cb4f99171f7ce36244c3f8669cd_mofchecker.log',
#    'mofchecker_updated_at': '2026-02-05T13:30:32Z'},
#   {'id': 180,
#    'structure': 'qmof-b4192d1.cif',
#    'md5': 'e765fd21c2e55927a13b44ad71f14688',
#    'is_mof': True,
#    'MOFQ': False,
#    'mofq_reason': 'check_failed:has_lone_molecule',
#    'mofchecker_blob': 'e765fd21c2e55927a13b44ad71f14688_mofchecker.json',
#    'mofchecker_log': 'logs/e765fd21c2e55927a13b44ad71f14688_mofchecker.log',
#    'mofchecker_updated_at': '2026-02-05T13:30:37Z'},
#   {'id': 181,
#    'structure': 'qmof-cb9ea13.cif',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': 'fe0d68fc6501829858ecb3504b2ca35e_mofchecker.json',
#    'mofchecker_log': 'logs/fe0d68fc6501829858ecb3504b2ca35e_mofchecker.log',
#    'mofchecker_updated_at': '2026-02-05T13:30:41Z'},
#   {'id': 182,
#    'structure': 'str_m4_o1_o4_acs_sym.68.cif',
#    'md5': '1c9a5d68fac18068899ecdbb6a47507f',
#    'is_mof': True,
#    'MOFQ': True,
#    'mofq_reason': None,
#    'mofchecker_blob': '1c9a5d68fac18068899ecdbb6a47507f_mofchecker.json',
#    'mofchecker_log': 'logs/1c9a5d68fac18068899ecdbb6a47507f_mofchecker.log',
#    'mofchecker_updated_at': '2026-01-20T18:36:56Z'}]}

# %%
df = pd.read_csv('../../AutoPrism/results/zeopp_metrics.csv')
api.update_zeopp_metrics(df)
# Out:
# {'created_count': 0,
#  'updated_count': 284,
#  'error_count': 0,
#  'created_records': [],
#  'updated_records': [{'id': 285,
#    'mof': '05000N2_ddec',
#    'md5': '38fa1a4a57d75602d1f962e5be326796',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 3.6688,
#    'Df': 2.21636,
#    'Dif': 3.6688,
#    'largest_included_sphere_diameter': 3.6688,
#    'largest_free_sphere_diameter': 2.21636,
#    'largest_included_sphere_diameter_along_free_sphere_path': 3.6688,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 1.04938},
#   {'id': 286,
#    'mof': '05000N2_ddec',
#    'md5': '38fa1a4a57d75602d1f962e5be326796',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 3.6688,
#    'Df': 2.21636,
#    'Dif': 3.6688,
#    'largest_included_sphere_diameter': 3.6688,
#    'largest_free_sphere_diameter': 2.21636,
#    'largest_included_sphere_diameter_along_free_sphere_path': 3.6688,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 1.04938},
#   {'id': 287,
#    'mof': '05000N2_ddec',
#    'md5': '38fa1a4a57d75602d1f962e5be326796',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 3.6688,
#    'Df': 2.21636,
#    'Dif': 3.6688,
#    'largest_included_sphere_diameter': 3.6688,
#    'largest_free_sphere_diameter': 2.21636,
#    'largest_included_sphere_diameter_along_free_sphere_path': 3.6688,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 1.04938},
#   {'id': 288,
#    'mof': '05001N2_ddec',
#    'md5': 'd09dd23c55c78b140591d8566883ebbc',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 19.34449,
#    'Df': 18.71956,
#    'Dif': 19.31133,
#    'largest_included_sphere_diameter': 19.34449,
#    'largest_free_sphere_diameter': 18.71956,
#    'largest_included_sphere_diameter_along_free_sphere_path': 19.31133,
#    'ASA_m2_per_g': 1943.61,
#    'POAV_cm3_per_g': 1.09046,
#    'POAV_fraction': 0.63845,
#    'Density_g_cm3': 0.585485},
#   {'id': 289,
#    'mof': '05001N2_ddec',
#    'md5': 'd09dd23c55c78b140591d8566883ebbc',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 19.34449,
#    'Df': 18.71956,
#    'Dif': 19.31133,
#    'largest_included_sphere_diameter': 19.34449,
#    'largest_free_sphere_diameter': 18.71956,
#    'largest_included_sphere_diameter_along_free_sphere_path': 19.31133,
#    'ASA_m2_per_g': 1926.54,
#    'POAV_cm3_per_g': 1.08935,
#    'POAV_fraction': 0.6378,
#    'Density_g_cm3': 0.585485},
#   {'id': 290,
#    'mof': '05001N2_ddec',
#    'md5': 'd09dd23c55c78b140591d8566883ebbc',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 19.34449,
#    'Df': 18.71956,
#    'Dif': 19.31133,
#    'largest_included_sphere_diameter': 19.34449,
#    'largest_free_sphere_diameter': 18.71956,
#    'largest_included_sphere_diameter_along_free_sphere_path': 19.31133,
#    'ASA_m2_per_g': 1886.82,
#    'POAV_cm3_per_g': 1.08669,
#    'POAV_fraction': 0.63624,
#    'Density_g_cm3': 0.585485},
#   {'id': 291,
#    'mof': '07000N2_ddec',
#    'md5': '17ca1f693001d5f4b62e9215cd6379eb',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 25.77046,
#    'Df': 25.37246,
#    'Dif': 25.77046,
#    'largest_included_sphere_diameter': 25.77046,
#    'largest_free_sphere_diameter': 25.37246,
#    'largest_included_sphere_diameter_along_free_sphere_path': 25.77046,
#    'ASA_m2_per_g': 2166.21,
#    'POAV_cm3_per_g': 1.53957,
#    'POAV_fraction': 0.70522,
#    'Density_g_cm3': 0.458062},
#   {'id': 292,
#    'mof': '07000N2_ddec',
#    'md5': '17ca1f693001d5f4b62e9215cd6379eb',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 25.77046,
#    'Df': 25.37246,
#    'Dif': 25.77046,
#    'largest_included_sphere_diameter': 25.77046,
#    'largest_free_sphere_diameter': 25.37246,
#    'largest_included_sphere_diameter_along_free_sphere_path': 25.77046,
#    'ASA_m2_per_g': 2141.96,
#    'POAV_cm3_per_g': 1.53839,
#    'POAV_fraction': 0.70468,
#    'Density_g_cm3': 0.458062},
#   {'id': 293,
#    'mof': '07000N2_ddec',
#    'md5': '17ca1f693001d5f4b62e9215cd6379eb',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 25.77046,
#    'Df': 25.37246,
#    'Dif': 25.77046,
#    'largest_included_sphere_diameter': 25.77046,
#    'largest_free_sphere_diameter': 25.37246,
#    'largest_included_sphere_diameter_along_free_sphere_path': 25.77046,
#    'ASA_m2_per_g': 2119.99,
#    'POAV_cm3_per_g': 1.53617,
#    'POAV_fraction': 0.70366,
#    'Density_g_cm3': 0.458062},
#   {'id': 294,
#    'mof': '07001N2_ddec',
#    'md5': '07efdb27d3ccf4e78e03da044906f917',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 7.48308,
#    'Df': 6.8544,
#    'Dif': 7.48308,
#    'largest_included_sphere_diameter': 7.48308,
#    'largest_free_sphere_diameter': 6.8544,
#    'largest_included_sphere_diameter_along_free_sphere_path': 7.48308,
#    'ASA_m2_per_g': 1175.19,
#    'POAV_cm3_per_g': 0.328785,
#    'POAV_fraction': 0.36174,
#    'Density_g_cm3': 1.10023},
#   {'id': 295,
#    'mof': '07001N2_ddec',
#    'md5': '07efdb27d3ccf4e78e03da044906f917',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 7.48308,
#    'Df': 6.8544,
#    'Dif': 7.48308,
#    'largest_included_sphere_diameter': 7.48308,
#    'largest_free_sphere_diameter': 6.8544,
#    'largest_included_sphere_diameter_along_free_sphere_path': 7.48308,
#    'ASA_m2_per_g': 1144.12,
#    'POAV_cm3_per_g': 0.32733,
#    'POAV_fraction': 0.36014,
#    'Density_g_cm3': 1.10023},
#   {'id': 296,
#    'mof': '07001N2_ddec',
#    'md5': '07efdb27d3ccf4e78e03da044906f917',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 7.48308,
#    'Df': 6.8544,
#    'Dif': 7.48308,
#    'largest_included_sphere_diameter': 7.48308,
#    'largest_free_sphere_diameter': 6.8544,
#    'largest_included_sphere_diameter_along_free_sphere_path': 7.48308,
#    'ASA_m2_per_g': 1094.72,
#    'POAV_cm3_per_g': 0.324604,
#    'POAV_fraction': 0.35714,
#    'Density_g_cm3': 1.10023},
#   {'id': 297,
#    'mof': '08000N3_ddec',
#    'md5': '1da8a7bc1aa56632455c6c2b643c2d7c',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 9.64939,
#    'Df': 5.36331,
#    'Dif': 9.59433,
#    'largest_included_sphere_diameter': 9.64939,
#    'largest_free_sphere_diameter': 5.36331,
#    'largest_included_sphere_diameter_along_free_sphere_path': 9.59433,
#    'ASA_m2_per_g': 4443.69,
#    'POAV_cm3_per_g': 1.22978,
#    'POAV_fraction': 0.63947,
#    'Density_g_cm3': 0.519987},
#   {'id': 298,
#    'mof': '08000N3_ddec',
#    'md5': '1da8a7bc1aa56632455c6c2b643c2d7c',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 9.64939,
#    'Df': 5.36331,
#    'Dif': 9.59433,
#    'largest_included_sphere_diameter': 9.64939,
#    'largest_free_sphere_diameter': 5.36331,
#    'largest_included_sphere_diameter_along_free_sphere_path': 9.59433,
#    'ASA_m2_per_g': 4402.84,
#    'POAV_cm3_per_g': 1.2274,
#    'POAV_fraction': 0.63823,
#    'Density_g_cm3': 0.519987},
#   {'id': 299,
#    'mof': '08000N3_ddec',
#    'md5': '1da8a7bc1aa56632455c6c2b643c2d7c',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 9.64939,
#    'Df': 5.36331,
#    'Dif': 9.59433,
#    'largest_included_sphere_diameter': 9.64939,
#    'largest_free_sphere_diameter': 5.36331,
#    'largest_included_sphere_diameter_along_free_sphere_path': 9.59433,
#    'ASA_m2_per_g': 4334.04,
#    'POAV_cm3_per_g': 1.22401,
#    'POAV_fraction': 0.63647,
#    'Density_g_cm3': 0.519987},
#   {'id': 300,
#    'mof': '15070N2_ddec',
#    'md5': 'c5c5b4ebd33465b24ded58a5d4f49b24',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 25.25256,
#    'Df': 25.0315,
#    'Dif': 25.25256,
#    'largest_included_sphere_diameter': 25.25256,
#    'largest_free_sphere_diameter': 25.0315,
#    'largest_included_sphere_diameter_along_free_sphere_path': 25.25256,
#    'ASA_m2_per_g': 2355.27,
#    'POAV_cm3_per_g': 1.58386,
#    'POAV_fraction': 0.69542,
#    'Density_g_cm3': 0.439066},
#   {'id': 301,
#    'mof': '15070N2_ddec',
#    'md5': 'c5c5b4ebd33465b24ded58a5d4f49b24',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 25.25256,
#    'Df': 25.0315,
#    'Dif': 25.25256,
#    'largest_included_sphere_diameter': 25.25256,
#    'largest_free_sphere_diameter': 25.0315,
#    'largest_included_sphere_diameter_along_free_sphere_path': 25.25256,
#    'ASA_m2_per_g': 2329.42,
#    'POAV_cm3_per_g': 1.58186,
#    'POAV_fraction': 0.69454,
#    'Density_g_cm3': 0.439066},
#   {'id': 302,
#    'mof': '15070N2_ddec',
#    'md5': 'c5c5b4ebd33465b24ded58a5d4f49b24',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 25.25256,
#    'Df': 25.0315,
#    'Dif': 25.25256,
#    'largest_included_sphere_diameter': 25.25256,
#    'largest_free_sphere_diameter': 25.0315,
#    'largest_included_sphere_diameter_along_free_sphere_path': 25.25256,
#    'ASA_m2_per_g': 2298.2,
#    'POAV_cm3_per_g': 1.57871,
#    'POAV_fraction': 0.69316,
#    'Density_g_cm3': 0.439066},
#   {'id': 303,
#    'mof': '16057N2_ddec',
#    'md5': '6202432f901e6b6d68c4dd3bc2ce866c',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 21.2838,
#    'Df': 20.73196,
#    'Dif': 21.2838,
#    'largest_included_sphere_diameter': 21.2838,
#    'largest_free_sphere_diameter': 20.73196,
#    'largest_included_sphere_diameter_along_free_sphere_path': 21.2838,
#    'ASA_m2_per_g': 1807.74,
#    'POAV_cm3_per_g': 1.06696,
#    'POAV_fraction': 0.65377,
#    'Density_g_cm3': 0.612741},
#   {'id': 304,
#    'mof': '16057N2_ddec',
#    'md5': '6202432f901e6b6d68c4dd3bc2ce866c',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 21.2838,
#    'Df': 20.73196,
#    'Dif': 21.2838,
#    'largest_included_sphere_diameter': 21.2838,
#    'largest_free_sphere_diameter': 20.73196,
#    'largest_included_sphere_diameter_along_free_sphere_path': 21.2838,
#    'ASA_m2_per_g': 1786.48,
#    'POAV_cm3_per_g': 1.06543,
#    'POAV_fraction': 0.65283,
#    'Density_g_cm3': 0.612741},
#   {'id': 305,
#    'mof': '16057N2_ddec',
#    'md5': '6202432f901e6b6d68c4dd3bc2ce866c',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 21.2838,
#    'Df': 20.73196,
#    'Dif': 21.2838,
#    'largest_included_sphere_diameter': 21.2838,
#    'largest_free_sphere_diameter': 20.73196,
#    'largest_included_sphere_diameter_along_free_sphere_path': 21.2838,
#    'ASA_m2_per_g': 1761.47,
#    'POAV_cm3_per_g': 1.06255,
#    'POAV_fraction': 0.65107,
#    'Density_g_cm3': 0.612741},
#   {'id': 306,
#    'mof': '17150N2_ddec',
#    'md5': 'dcc908a9605f5f513d6a7a1d220b25ef',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 24.53845,
#    'Df': 24.34771,
#    'Dif': 24.53845,
#    'largest_included_sphere_diameter': 24.53845,
#    'largest_free_sphere_diameter': 24.34771,
#    'largest_included_sphere_diameter_along_free_sphere_path': 24.53845,
#    'ASA_m2_per_g': 2391.15,
#    'POAV_cm3_per_g': 1.47403,
#    'POAV_fraction': 0.65957,
#    'Density_g_cm3': 0.447461},
#   {'id': 307,
#    'mof': '17150N2_ddec',
#    'md5': 'dcc908a9605f5f513d6a7a1d220b25ef',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 24.53845,
#    'Df': 24.34771,
#    'Dif': 24.53845,
#    'largest_included_sphere_diameter': 24.53845,
#    'largest_free_sphere_diameter': 24.34771,
#    'largest_included_sphere_diameter_along_free_sphere_path': 24.53845,
#    'ASA_m2_per_g': 2375.69,
#    'POAV_cm3_per_g': 1.47133,
#    'POAV_fraction': 0.65836,
#    'Density_g_cm3': 0.447461},
#   {'id': 308,
#    'mof': '17150N2_ddec',
#    'md5': 'dcc908a9605f5f513d6a7a1d220b25ef',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 24.53845,
#    'Df': 24.34771,
#    'Dif': 24.53845,
#    'largest_included_sphere_diameter': 24.53845,
#    'largest_free_sphere_diameter': 24.34771,
#    'largest_included_sphere_diameter_along_free_sphere_path': 24.53845,
#    'ASA_m2_per_g': 2344.12,
#    'POAV_cm3_per_g': 1.46808,
#    'POAV_fraction': 0.65691,
#    'Density_g_cm3': 0.447461},
#   {'id': 309,
#    'mof': '19020N3_ddec',
#    'md5': '9d1d4333c36c84121f85fd95f7112c6e',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 11.42647,
#    'Df': 8.65437,
#    'Dif': 10.84008,
#    'largest_included_sphere_diameter': 11.42647,
#    'largest_free_sphere_diameter': 8.65437,
#    'largest_included_sphere_diameter_along_free_sphere_path': 10.84008,
#    'ASA_m2_per_g': 6572.82,
#    'POAV_cm3_per_g': 2.50335,
#    'POAV_fraction': 0.80817,
#    'Density_g_cm3': 0.322836},
#   {'id': 310,
#    'mof': '19020N3_ddec',
#    'md5': '9d1d4333c36c84121f85fd95f7112c6e',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 11.42647,
#    'Df': 8.65437,
#    'Dif': 10.84008,
#    'largest_included_sphere_diameter': 11.42647,
#    'largest_free_sphere_diameter': 8.65437,
#    'largest_included_sphere_diameter_along_free_sphere_path': 10.84008,
#    'ASA_m2_per_g': 6585.3,
#    'POAV_cm3_per_g': 2.50102,
#    'POAV_fraction': 0.80742,
#    'Density_g_cm3': 0.322836},
#   {'id': 311,
#    'mof': '19020N3_ddec',
#    'md5': '9d1d4333c36c84121f85fd95f7112c6e',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 11.42647,
#    'Df': 8.65437,
#    'Dif': 10.84008,
#    'largest_included_sphere_diameter': 11.42647,
#    'largest_free_sphere_diameter': 8.65437,
#    'largest_included_sphere_diameter_along_free_sphere_path': 10.84008,
#    'ASA_m2_per_g': 6604.96,
#    'POAV_cm3_per_g': 2.49672,
#    'POAV_fraction': 0.80603,
#    'Density_g_cm3': 0.322836},
#   {'id': 312,
#    'mof': '20051N2_ddec',
#    'md5': '7409057b99b5ac68066d923ded4ca2a8',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 26.51283,
#    'Df': 26.20962,
#    'Dif': 26.51025,
#    'largest_included_sphere_diameter': 26.51283,
#    'largest_free_sphere_diameter': 26.20962,
#    'largest_included_sphere_diameter_along_free_sphere_path': 26.51025,
#    'ASA_m2_per_g': 2208.46,
#    'POAV_cm3_per_g': 1.50034,
#    'POAV_fraction': 0.69444,
#    'Density_g_cm3': 0.462854},
#   {'id': 313,
#    'mof': '20051N2_ddec',
#    'md5': '7409057b99b5ac68066d923ded4ca2a8',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 26.51283,
#    'Df': 26.20962,
#    'Dif': 26.51025,
#    'largest_included_sphere_diameter': 26.51283,
#    'largest_free_sphere_diameter': 26.20962,
#    'largest_included_sphere_diameter_along_free_sphere_path': 26.51025,
#    'ASA_m2_per_g': 2186.72,
#    'POAV_cm3_per_g': 1.49872,
#    'POAV_fraction': 0.69369,
#    'Density_g_cm3': 0.462854},
#   {'id': 314,
#    'mof': '20051N2_ddec',
#    'md5': '7409057b99b5ac68066d923ded4ca2a8',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 26.51283,
#    'Df': 26.20962,
#    'Dif': 26.51025,
#    'largest_included_sphere_diameter': 26.51283,
#    'largest_free_sphere_diameter': 26.20962,
#    'largest_included_sphere_diameter_along_free_sphere_path': 26.51025,
#    'ASA_m2_per_g': 2156.48,
#    'POAV_cm3_per_g': 1.49617,
#    'POAV_fraction': 0.69251,
#    'Density_g_cm3': 0.462854},
#   {'id': 315,
#    'mof': '20590N2_ddec',
#    'md5': '735702b3d8c787aa19784f8b53bb6c9e',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 25.9921,
#    'Df': 25.66617,
#    'Dif': 25.9921,
#    'largest_included_sphere_diameter': 25.9921,
#    'largest_free_sphere_diameter': 25.66617,
#    'largest_included_sphere_diameter_along_free_sphere_path': 25.9921,
#    'ASA_m2_per_g': 2315.18,
#    'POAV_cm3_per_g': 1.28917,
#    'POAV_fraction': 0.65066,
#    'Density_g_cm3': 0.504711},
#   {'id': 316,
#    'mof': '20590N2_ddec',
#    'md5': '735702b3d8c787aa19784f8b53bb6c9e',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 25.9921,
#    'Df': 25.66617,
#    'Dif': 25.9921,
#    'largest_included_sphere_diameter': 25.9921,
#    'largest_free_sphere_diameter': 25.66617,
#    'largest_included_sphere_diameter_along_free_sphere_path': 25.9921,
#    'ASA_m2_per_g': 2261.14,
#    'POAV_cm3_per_g': 1.28519,
#    'POAV_fraction': 0.64865,
#    'Density_g_cm3': 0.504711},
#   {'id': 317,
#    'mof': '20590N2_ddec',
#    'md5': '735702b3d8c787aa19784f8b53bb6c9e',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 25.9921,
#    'Df': 25.66617,
#    'Dif': 25.9921,
#    'largest_included_sphere_diameter': 25.9921,
#    'largest_free_sphere_diameter': 25.66617,
#    'largest_included_sphere_diameter_along_free_sphere_path': 25.9921,
#    'ASA_m2_per_g': 2163.04,
#    'POAV_cm3_per_g': 1.27277,
#    'POAV_fraction': 0.64238,
#    'Density_g_cm3': 0.504711},
#   {'id': 318,
#    'mof': '21030N2_ddec',
#    'md5': '7366b13430080588504f0bf8bd2a387f',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 19.27673,
#    'Df': 18.94015,
#    'Dif': 19.27673,
#    'largest_included_sphere_diameter': 19.27673,
#    'largest_free_sphere_diameter': 18.94015,
#    'largest_included_sphere_diameter_along_free_sphere_path': 19.27673,
#    'ASA_m2_per_g': 1785.8,
#    'POAV_cm3_per_g': 0.854138,
#    'POAV_fraction': 0.5237,
#    'Density_g_cm3': 0.613133},
#   {'id': 319,
#    'mof': '21030N2_ddec',
#    'md5': '7366b13430080588504f0bf8bd2a387f',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 19.27673,
#    'Df': 18.94015,
#    'Dif': 19.27673,
#    'largest_included_sphere_diameter': 19.27673,
#    'largest_free_sphere_diameter': 18.94015,
#    'largest_included_sphere_diameter_along_free_sphere_path': 19.27673,
#    'ASA_m2_per_g': 1751.65,
#    'POAV_cm3_per_g': 0.851936,
#    'POAV_fraction': 0.52235,
#    'Density_g_cm3': 0.613133},
#   {'id': 320,
#    'mof': '21030N2_ddec',
#    'md5': '7366b13430080588504f0bf8bd2a387f',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 19.27673,
#    'Df': 18.94015,
#    'Dif': 19.27673,
#    'largest_included_sphere_diameter': 19.27673,
#    'largest_free_sphere_diameter': 18.94015,
#    'largest_included_sphere_diameter_along_free_sphere_path': 19.27673,
#    'ASA_m2_per_g': 1702.7,
#    'POAV_cm3_per_g': 0.849702,
#    'POAV_fraction': 0.52098,
#    'Density_g_cm3': 0.613133},
#   {'id': 321,
#    'mof': '22108N2_ddec',
#    'md5': 'b658efcf311744888b772d09151f8e92',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 20.15565,
#    'Df': 19.81714,
#    'Dif': 20.15393,
#    'largest_included_sphere_diameter': 20.15565,
#    'largest_free_sphere_diameter': 19.81714,
#    'largest_included_sphere_diameter_along_free_sphere_path': 20.15393,
#    'ASA_m2_per_g': 2124.36,
#    'POAV_cm3_per_g': 0.904405,
#    'POAV_fraction': 0.54874,
#    'Density_g_cm3': 0.606741},
#   {'id': 322,
#    'mof': '22108N2_ddec',
#    'md5': 'b658efcf311744888b772d09151f8e92',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 20.15565,
#    'Df': 19.81714,
#    'Dif': 20.15393,
#    'largest_included_sphere_diameter': 20.15565,
#    'largest_free_sphere_diameter': 19.81714,
#    'largest_included_sphere_diameter_along_free_sphere_path': 20.15393,
#    'ASA_m2_per_g': 2090.73,
#    'POAV_cm3_per_g': 0.901488,
#    'POAV_fraction': 0.54697,
#    'Density_g_cm3': 0.606741},
#   {'id': 323,
#    'mof': '22108N2_ddec',
#    'md5': 'b658efcf311744888b772d09151f8e92',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 20.15565,
#    'Df': 19.81714,
#    'Dif': 20.15393,
#    'largest_included_sphere_diameter': 20.15565,
#    'largest_free_sphere_diameter': 19.81714,
#    'largest_included_sphere_diameter_along_free_sphere_path': 20.15393,
#    'ASA_m2_per_g': 2032.92,
#    'POAV_cm3_per_g': 0.896346,
#    'POAV_fraction': 0.54385,
#    'Density_g_cm3': 0.606741},
#   {'id': 324,
#    'mof': '22221N2_ddec',
#    'md5': '544145e69898ec2ce922aaf64b32bafa',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 58.40782,
#    'Df': 58.23805,
#    'Dif': 58.40782,
#    'largest_included_sphere_diameter': 58.40782,
#    'largest_free_sphere_diameter': 58.23805,
#    'largest_included_sphere_diameter_along_free_sphere_path': 58.40782,
#    'ASA_m2_per_g': 2760.81,
#    'POAV_cm3_per_g': 3.87545,
#    'POAV_fraction': 0.83541,
#    'Density_g_cm3': 0.215565},
#   {'id': 325,
#    'mof': '22221N2_ddec',
#    'md5': '544145e69898ec2ce922aaf64b32bafa',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 58.40782,
#    'Df': 58.23805,
#    'Dif': 58.40782,
#    'largest_included_sphere_diameter': 58.40782,
#    'largest_free_sphere_diameter': 58.23805,
#    'largest_included_sphere_diameter_along_free_sphere_path': 58.40782,
#    'ASA_m2_per_g': 2736.59,
#    'POAV_cm3_per_g': 3.87382,
#    'POAV_fraction': 0.83506,
#    'Density_g_cm3': 0.215565},
#   {'id': 326,
#    'mof': '22221N2_ddec',
#    'md5': '544145e69898ec2ce922aaf64b32bafa',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 58.40782,
#    'Df': 58.23805,
#    'Dif': 58.40782,
#    'largest_included_sphere_diameter': 58.40782,
#    'largest_free_sphere_diameter': 58.23805,
#    'largest_included_sphere_diameter_along_free_sphere_path': 58.40782,
#    'ASA_m2_per_g': 2709.67,
#    'POAV_cm3_per_g': 3.87053,
#    'POAV_fraction': 0.83435,
#    'Density_g_cm3': 0.215565},
#   {'id': 327,
#    'mof': '22551N2_ddec',
#    'md5': 'd3e2466eb9415ff422be4bea2e1a074a',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 10.87456,
#    'Df': 10.23471,
#    'Dif': 10.87456,
#    'largest_included_sphere_diameter': 10.87456,
#    'largest_free_sphere_diameter': 10.23471,
#    'largest_included_sphere_diameter_along_free_sphere_path': 10.87456,
#    'ASA_m2_per_g': 743.443,
#    'POAV_cm3_per_g': 0.258845,
#    'POAV_fraction': 0.27276,
#    'Density_g_cm3': 1.05376},
#   {'id': 328,
#    'mof': '22551N2_ddec',
#    'md5': 'd3e2466eb9415ff422be4bea2e1a074a',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 10.87456,
#    'Df': 10.23471,
#    'Dif': 10.87456,
#    'largest_included_sphere_diameter': 10.87456,
#    'largest_free_sphere_diameter': 10.23471,
#    'largest_included_sphere_diameter_along_free_sphere_path': 10.87456,
#    'ASA_m2_per_g': 730.874,
#    'POAV_cm3_per_g': 0.257621,
#    'POAV_fraction': 0.27147,
#    'Density_g_cm3': 1.05376},
#   {'id': 329,
#    'mof': '22551N2_ddec',
#    'md5': 'd3e2466eb9415ff422be4bea2e1a074a',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 10.87456,
#    'Df': 10.23471,
#    'Dif': 10.87456,
#    'largest_included_sphere_diameter': 10.87456,
#    'largest_free_sphere_diameter': 10.23471,
#    'largest_included_sphere_diameter_along_free_sphere_path': 10.87456,
#    'ASA_m2_per_g': 711.408,
#    'POAV_cm3_per_g': 0.25633,
#    'POAV_fraction': 0.27011,
#    'Density_g_cm3': 1.05376},
#   {'id': 330,
#    'mof': 'ASEJOZ',
#    'md5': 'cc5178b74a53bf9ec963c6df0fde4c6e',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 4.05493,
#    'Df': 3.26882,
#    'Dif': 4.04345,
#    'largest_included_sphere_diameter': 4.05493,
#    'largest_free_sphere_diameter': 3.26882,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.04345,
#    'ASA_m2_per_g': 294.64,
#    'POAV_cm3_per_g': 0.0857005,
#    'POAV_fraction': 0.16697,
#    'Density_g_cm3': 1.9483},
#   {'id': 331,
#    'mof': 'ASEJOZ',
#    'md5': 'cc5178b74a53bf9ec963c6df0fde4c6e',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 4.05493,
#    'Df': 3.26882,
#    'Dif': 4.04345,
#    'largest_included_sphere_diameter': 4.05493,
#    'largest_free_sphere_diameter': 3.26882,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.04345,
#    'ASA_m2_per_g': 249.267,
#    'POAV_cm3_per_g': 0.082236,
#    'POAV_fraction': 0.16022,
#    'Density_g_cm3': 1.9483},
#   {'id': 332,
#    'mof': 'ASEJOZ',
#    'md5': 'cc5178b74a53bf9ec963c6df0fde4c6e',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 4.05493,
#    'Df': 3.26882,
#    'Dif': 4.04345,
#    'largest_included_sphere_diameter': 4.05493,
#    'largest_free_sphere_diameter': 3.26882,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.04345,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 1.9483},
#   {'id': 333,
#    'mof': 'ASEJOZ01_clean',
#    'md5': '08759f403a58b6b0a11029bc8cb2551d',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 4.24703,
#    'Df': 3.71528,
#    'Dif': 4.24703,
#    'largest_included_sphere_diameter': 4.24703,
#    'largest_free_sphere_diameter': 3.71528,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.24703,
#    'ASA_m2_per_g': 398.563,
#    'POAV_cm3_per_g': 0.111205,
#    'POAV_fraction': 0.19446,
#    'Density_g_cm3': 1.74866},
#   {'id': 334,
#    'mof': 'ASEJOZ01_clean',
#    'md5': '08759f403a58b6b0a11029bc8cb2551d',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 4.24703,
#    'Df': 3.71528,
#    'Dif': 4.24703,
#    'largest_included_sphere_diameter': 4.24703,
#    'largest_free_sphere_diameter': 3.71528,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.24703,
#    'ASA_m2_per_g': 365.247,
#    'POAV_cm3_per_g': 0.108895,
#    'POAV_fraction': 0.19042,
#    'Density_g_cm3': 1.74866},
#   {'id': 335,
#    'mof': 'ASEJOZ01_clean',
#    'md5': '08759f403a58b6b0a11029bc8cb2551d',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 4.24703,
#    'Df': 3.71528,
#    'Dif': 4.24703,
#    'largest_included_sphere_diameter': 4.24703,
#    'largest_free_sphere_diameter': 3.71528,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.24703,
#    'ASA_m2_per_g': 314.592,
#    'POAV_cm3_per_g': 0.103863,
#    'POAV_fraction': 0.18162,
#    'Density_g_cm3': 1.74866},
#   {'id': 336,
#    'mof': 'AWASAU_clean',
#    'md5': '7a1f8ff0a9b0555ff9a97c5895ae30a2',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 4.65651,
#    'Df': 4.0975,
#    'Dif': 4.55932,
#    'largest_included_sphere_diameter': 4.65651,
#    'largest_free_sphere_diameter': 4.0975,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.55932,
#    'ASA_m2_per_g': 425.135,
#    'POAV_cm3_per_g': 0.112723,
#    'POAV_fraction': 0.267,
#    'Density_g_cm3': 2.36864},
#   {'id': 337,
#    'mof': 'AWASAU_clean',
#    'md5': '7a1f8ff0a9b0555ff9a97c5895ae30a2',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 4.65651,
#    'Df': 4.0975,
#    'Dif': 4.55932,
#    'largest_included_sphere_diameter': 4.65651,
#    'largest_free_sphere_diameter': 4.0975,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.55932,
#    'ASA_m2_per_g': 401.944,
#    'POAV_cm3_per_g': 0.110675,
#    'POAV_fraction': 0.26215,
#    'Density_g_cm3': 2.36864},
#   {'id': 338,
#    'mof': 'AWASAU_clean',
#    'md5': '7a1f8ff0a9b0555ff9a97c5895ae30a2',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 4.65651,
#    'Df': 4.0975,
#    'Dif': 4.55932,
#    'largest_included_sphere_diameter': 4.65651,
#    'largest_free_sphere_diameter': 4.0975,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.55932,
#    'ASA_m2_per_g': 359.263,
#    'POAV_cm3_per_g': 0.107539,
#    'POAV_fraction': 0.25472,
#    'Density_g_cm3': 2.36864},
#   {'id': 339,
#    'mof': 'AWASOI_clean',
#    'md5': '5dbfdd322670ead4c997b84b2f6e4997',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 5.00203,
#    'Df': 3.94467,
#    'Dif': 4.63846,
#    'largest_included_sphere_diameter': 5.00203,
#    'largest_free_sphere_diameter': 3.94467,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.63846,
#    'ASA_m2_per_g': 449.972,
#    'POAV_cm3_per_g': 0.107732,
#    'POAV_fraction': 0.25443,
#    'Density_g_cm3': 2.36169},
#   {'id': 340,
#    'mof': 'AWASOI_clean',
#    'md5': '5dbfdd322670ead4c997b84b2f6e4997',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 5.00203,
#    'Df': 3.94467,
#    'Dif': 4.63846,
#    'largest_included_sphere_diameter': 5.00203,
#    'largest_free_sphere_diameter': 3.94467,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.63846,
#    'ASA_m2_per_g': 421.238,
#    'POAV_cm3_per_g': 0.105488,
#    'POAV_fraction': 0.24913,
#    'Density_g_cm3': 2.36169},
#   {'id': 341,
#    'mof': 'AWASOI_clean',
#    'md5': '5dbfdd322670ead4c997b84b2f6e4997',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 5.00203,
#    'Df': 3.94467,
#    'Dif': 4.63846,
#    'largest_included_sphere_diameter': 5.00203,
#    'largest_free_sphere_diameter': 3.94467,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.63846,
#    'ASA_m2_per_g': 381.147,
#    'POAV_cm3_per_g': 0.102126,
#    'POAV_fraction': 0.24119,
#    'Density_g_cm3': 2.36169},
#   {'id': 342,
#    'mof': 'BETGUE_clean',
#    'md5': 'a1dd3ef62f00e5c1251fa7873d16f977',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 15.48849,
#    'Df': 9.94567,
#    'Dif': 15.48849,
#    'largest_included_sphere_diameter': 15.48849,
#    'largest_free_sphere_diameter': 9.94567,
#    'largest_included_sphere_diameter_along_free_sphere_path': 15.48849,
#    'ASA_m2_per_g': 1786.08,
#    'POAV_cm3_per_g': 0.715123,
#    'POAV_fraction': 0.52577,
#    'Density_g_cm3': 0.735216},
#   {'id': 343,
#    'mof': 'BETGUE_clean',
#    'md5': 'a1dd3ef62f00e5c1251fa7873d16f977',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 15.48849,
#    'Df': 9.94567,
#    'Dif': 15.48849,
#    'largest_included_sphere_diameter': 15.48849,
#    'largest_free_sphere_diameter': 9.94567,
#    'largest_included_sphere_diameter_along_free_sphere_path': 15.48849,
#    'ASA_m2_per_g': 1776.23,
#    'POAV_cm3_per_g': 0.714035,
#    'POAV_fraction': 0.52497,
#    'Density_g_cm3': 0.735216},
#   {'id': 344,
#    'mof': 'BETGUE_clean',
#    'md5': 'a1dd3ef62f00e5c1251fa7873d16f977',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 15.48849,
#    'Df': 9.94567,
#    'Dif': 15.48849,
#    'largest_included_sphere_diameter': 15.48849,
#    'largest_free_sphere_diameter': 9.94567,
#    'largest_included_sphere_diameter_along_free_sphere_path': 15.48849,
#    'ASA_m2_per_g': 1756.76,
#    'POAV_cm3_per_g': 0.712797,
#    'POAV_fraction': 0.52406,
#    'Density_g_cm3': 0.735216},
#   {'id': 345,
#    'mof': 'CANRUG_clean',
#    'md5': '24c4b2e063d1dc866baa37b97750c927',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 6.2836,
#    'Df': 4.66591,
#    'Dif': 6.27816,
#    'largest_included_sphere_diameter': 6.2836,
#    'largest_free_sphere_diameter': 4.66591,
#    'largest_included_sphere_diameter_along_free_sphere_path': 6.27816,
#    'ASA_m2_per_g': 2215.56,
#    'POAV_cm3_per_g': 0.511934,
#    'POAV_fraction': 0.45284,
#    'Density_g_cm3': 0.884567},
#   {'id': 346,
#    'mof': 'CANRUG_clean',
#    'md5': '24c4b2e063d1dc866baa37b97750c927',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 6.2836,
#    'Df': 4.66591,
#    'Dif': 6.27816,
#    'largest_included_sphere_diameter': 6.2836,
#    'largest_free_sphere_diameter': 4.66591,
#    'largest_included_sphere_diameter_along_free_sphere_path': 6.27816,
#    'ASA_m2_per_g': 2116.82,
#    'POAV_cm3_per_g': 0.506892,
#    'POAV_fraction': 0.44838,
#    'Density_g_cm3': 0.884567},
#   {'id': 347,
#    'mof': 'CANRUG_clean',
#    'md5': '24c4b2e063d1dc866baa37b97750c927',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 6.2836,
#    'Df': 4.66591,
#    'Dif': 6.27816,
#    'largest_included_sphere_diameter': 6.2836,
#    'largest_free_sphere_diameter': 4.66591,
#    'largest_included_sphere_diameter_along_free_sphere_path': 6.27816,
#    'ASA_m2_per_g': 1951.08,
#    'POAV_cm3_per_g': 0.499487,
#    'POAV_fraction': 0.44183,
#    'Density_g_cm3': 0.884567},
#   {'id': 348,
#    'mof': 'COCNAL_clean',
#    'md5': '6bcb6439e8f347913711b02170ec714f',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 10.67323,
#    'Df': 6.46844,
#    'Dif': 10.66539,
#    'largest_included_sphere_diameter': 10.67323,
#    'largest_free_sphere_diameter': 6.46844,
#    'largest_included_sphere_diameter_along_free_sphere_path': 10.66539,
#    'ASA_m2_per_g': 3703.58,
#    'POAV_cm3_per_g': 1.07072,
#    'POAV_fraction': 0.7002,
#    'Density_g_cm3': 0.653951},
#   {'id': 349,
#    'mof': 'COCNAL_clean',
#    'md5': '6bcb6439e8f347913711b02170ec714f',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 10.67323,
#    'Df': 6.46844,
#    'Dif': 10.66539,
#    'largest_included_sphere_diameter': 10.67323,
#    'largest_free_sphere_diameter': 6.46844,
#    'largest_included_sphere_diameter_along_free_sphere_path': 10.66539,
#    'ASA_m2_per_g': 3668.6,
#    'POAV_cm3_per_g': 1.06736,
#    'POAV_fraction': 0.698,
#    'Density_g_cm3': 0.653951},
#   {'id': 350,
#    'mof': 'COCNAL_clean',
#    'md5': '6bcb6439e8f347913711b02170ec714f',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 10.67323,
#    'Df': 6.46844,
#    'Dif': 10.66539,
#    'largest_included_sphere_diameter': 10.67323,
#    'largest_free_sphere_diameter': 6.46844,
#    'largest_included_sphere_diameter_along_free_sphere_path': 10.66539,
#    'ASA_m2_per_g': 3625.82,
#    'POAV_cm3_per_g': 1.06308,
#    'POAV_fraction': 0.6952,
#    'Density_g_cm3': 0.653951},
#   {'id': 351,
#    'mof': 'COYTIU_clean',
#    'md5': '03f7703dafeb0be983c3a69dd7c4a6f3',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 3.82865,
#    'Df': 3.25353,
#    'Dif': 3.82172,
#    'largest_included_sphere_diameter': 3.82865,
#    'largest_free_sphere_diameter': 3.25353,
#    'largest_included_sphere_diameter_along_free_sphere_path': 3.82172,
#    'ASA_m2_per_g': 489.095,
#    'POAV_cm3_per_g': 0.145275,
#    'POAV_fraction': 0.2608,
#    'Density_g_cm3': 1.79522},
#   {'id': 352,
#    'mof': 'COYTIU_clean',
#    'md5': '03f7703dafeb0be983c3a69dd7c4a6f3',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 3.82865,
#    'Df': 3.25353,
#    'Dif': 3.82172,
#    'largest_included_sphere_diameter': 3.82865,
#    'largest_free_sphere_diameter': 3.25353,
#    'largest_included_sphere_diameter_along_free_sphere_path': 3.82172,
#    'ASA_m2_per_g': 413.087,
#    'POAV_cm3_per_g': 0.134123,
#    'POAV_fraction': 0.24078,
#    'Density_g_cm3': 1.79522},
#   {'id': 353,
#    'mof': 'COYTIU_clean',
#    'md5': '03f7703dafeb0be983c3a69dd7c4a6f3',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 3.82865,
#    'Df': 3.25353,
#    'Dif': 3.82172,
#    'largest_included_sphere_diameter': 3.82865,
#    'largest_free_sphere_diameter': 3.25353,
#    'largest_included_sphere_diameter_along_free_sphere_path': 3.82172,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 1.79522},
#   {'id': 354,
#    'mof': 'COYTOA_clean',
#    'md5': '9e1ff3085eb6946df2cf2293741bbf6f',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 3.82333,
#    'Df': 3.12859,
#    'Dif': 3.7056,
#    'largest_included_sphere_diameter': 3.82333,
#    'largest_free_sphere_diameter': 3.12859,
#    'largest_included_sphere_diameter_along_free_sphere_path': 3.7056,
#    'ASA_m2_per_g': 454.955,
#    'POAV_cm3_per_g': 0.131497,
#    'POAV_fraction': 0.24741,
#    'Density_g_cm3': 1.88149},
#   {'id': 355,
#    'mof': 'COYTOA_clean',
#    'md5': '9e1ff3085eb6946df2cf2293741bbf6f',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 3.82333,
#    'Df': 3.12859,
#    'Dif': 3.7056,
#    'largest_included_sphere_diameter': 3.82333,
#    'largest_free_sphere_diameter': 3.12859,
#    'largest_included_sphere_diameter_along_free_sphere_path': 3.7056,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 1.88149},
#   {'id': 356,
#    'mof': 'COYTOA_clean',
#    'md5': '9e1ff3085eb6946df2cf2293741bbf6f',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 3.82333,
#    'Df': 3.12859,
#    'Dif': 3.7056,
#    'largest_included_sphere_diameter': 3.82333,
#    'largest_free_sphere_diameter': 3.12859,
#    'largest_included_sphere_diameter_along_free_sphere_path': 3.7056,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 1.88149},
#   {'id': 357,
#    'mof': 'DATPIY_clean',
#    'md5': '30ff4e93f130f8fa5e34bdab55e50f91',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 4.99384,
#    'Df': 3.37029,
#    'Dif': 4.99384,
#    'largest_included_sphere_diameter': 4.99384,
#    'largest_free_sphere_diameter': 3.37029,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.99384,
#    'ASA_m2_per_g': 302.102,
#    'POAV_cm3_per_g': 0.0848456,
#    'POAV_fraction': 0.20641,
#    'Density_g_cm3': 2.43277},
#   {'id': 358,
#    'mof': 'DATPIY_clean',
#    'md5': '30ff4e93f130f8fa5e34bdab55e50f91',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 4.99384,
#    'Df': 3.37029,
#    'Dif': 4.99384,
#    'largest_included_sphere_diameter': 4.99384,
#    'largest_free_sphere_diameter': 3.37029,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.99384,
#    'ASA_m2_per_g': 280.619,
#    'POAV_cm3_per_g': 0.0835137,
#    'POAV_fraction': 0.20317,
#    'Density_g_cm3': 2.43277},
#   {'id': 359,
#    'mof': 'DATPIY_clean',
#    'md5': '30ff4e93f130f8fa5e34bdab55e50f91',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 4.99384,
#    'Df': 3.37029,
#    'Dif': 4.99384,
#    'largest_included_sphere_diameter': 4.99384,
#    'largest_free_sphere_diameter': 3.37029,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.99384,
#    'ASA_m2_per_g': 239.39,
#    'POAV_cm3_per_g': 0.0813804,
#    'POAV_fraction': 0.19798,
#    'Density_g_cm3': 2.43277},
#   {'id': 360,
#    'mof': 'DOMDAL_clean',
#    'md5': '1c8df5a6518a25c482f264f3bedd2162',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 18.41792,
#    'Df': 14.47697,
#    'Dif': 18.40939,
#    'largest_included_sphere_diameter': 18.41792,
#    'largest_free_sphere_diameter': 14.47697,
#    'largest_included_sphere_diameter_along_free_sphere_path': 18.40939,
#    'ASA_m2_per_g': 2071.76,
#    'POAV_cm3_per_g': 1.09059,
#    'POAV_fraction': 0.72338,
#    'Density_g_cm3': 0.66329},
#   {'id': 361,
#    'mof': 'DOMDAL_clean',
#    'md5': '1c8df5a6518a25c482f264f3bedd2162',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 18.41792,
#    'Df': 14.47697,
#    'Dif': 18.40939,
#    'largest_included_sphere_diameter': 18.41792,
#    'largest_free_sphere_diameter': 14.47697,
#    'largest_included_sphere_diameter_along_free_sphere_path': 18.40939,
#    'ASA_m2_per_g': 2058.66,
#    'POAV_cm3_per_g': 1.08815,
#    'POAV_fraction': 0.72176,
#    'Density_g_cm3': 0.66329},
#   {'id': 362,
#    'mof': 'DOMDAL_clean',
#    'md5': '1c8df5a6518a25c482f264f3bedd2162',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 18.41792,
#    'Df': 14.47697,
#    'Dif': 18.40939,
#    'largest_included_sphere_diameter': 18.41792,
#    'largest_free_sphere_diameter': 14.47697,
#    'largest_included_sphere_diameter_along_free_sphere_path': 18.40939,
#    'ASA_m2_per_g': 2029.99,
#    'POAV_cm3_per_g': 1.08401,
#    'POAV_fraction': 0.71901,
#    'Density_g_cm3': 0.66329},
#   {'id': 363,
#    'mof': 'DOQGUM_clean',
#    'md5': '6ea3e5b31fb913bef56fa95cd0b3277b',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 3.60628,
#    'Df': 3.07511,
#    'Dif': 3.59812,
#    'largest_included_sphere_diameter': 3.60628,
#    'largest_free_sphere_diameter': 3.07511,
#    'largest_included_sphere_diameter_along_free_sphere_path': 3.59812,
#    'ASA_m2_per_g': 136.165,
#    'POAV_cm3_per_g': 0.0872801,
#    'POAV_fraction': 0.19936,
#    'Density_g_cm3': 2.28414},
#   {'id': 364,
#    'mof': 'DOQGUM_clean',
#    'md5': '6ea3e5b31fb913bef56fa95cd0b3277b',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 3.60628,
#    'Df': 3.07511,
#    'Dif': 3.59812,
#    'largest_included_sphere_diameter': 3.60628,
#    'largest_free_sphere_diameter': 3.07511,
#    'largest_included_sphere_diameter_along_free_sphere_path': 3.59812,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 2.28414},
#   {'id': 365,
#    'mof': 'DOQGUM_clean',
#    'md5': '6ea3e5b31fb913bef56fa95cd0b3277b',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 3.60628,
#    'Df': 3.07511,
#    'Dif': 3.59812,
#    'largest_included_sphere_diameter': 3.60628,
#    'largest_free_sphere_diameter': 3.07511,
#    'largest_included_sphere_diameter_along_free_sphere_path': 3.59812,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 2.28414},
#   {'id': 366,
#    'mof': 'DOQHIB_clean',
#    'md5': 'c08661d58bb7f0074ad15203cad215dd',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 3.58421,
#    'Df': 3.05069,
#    'Dif': 3.56558,
#    'largest_included_sphere_diameter': 3.58421,
#    'largest_free_sphere_diameter': 3.05069,
#    'largest_included_sphere_diameter_along_free_sphere_path': 3.56558,
#    'ASA_m2_per_g': 58.7507,
#    'POAV_cm3_per_g': 0.0379512,
#    'POAV_fraction': 0.09,
#    'Density_g_cm3': 2.37147},
#   {'id': 367,
#    'mof': 'DOQHIB_clean',
#    'md5': 'c08661d58bb7f0074ad15203cad215dd',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 3.58421,
#    'Df': 3.05069,
#    'Dif': 3.56558,
#    'largest_included_sphere_diameter': 3.58421,
#    'largest_free_sphere_diameter': 3.05069,
#    'largest_included_sphere_diameter_along_free_sphere_path': 3.56558,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 2.37147},
#   {'id': 368,
#    'mof': 'DOQHIB_clean',
#    'md5': 'c08661d58bb7f0074ad15203cad215dd',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 3.58421,
#    'Df': 3.05069,
#    'Dif': 3.56558,
#    'largest_included_sphere_diameter': 3.58421,
#    'largest_free_sphere_diameter': 3.05069,
#    'largest_included_sphere_diameter_along_free_sphere_path': 3.56558,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 2.37147},
#   {'id': 369,
#    'mof': 'ELILER_clean',
#    'md5': '24f47e65b0de4fd3c8f0453923375334',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 4.6076,
#    'Df': 3.59111,
#    'Dif': 4.6076,
#    'largest_included_sphere_diameter': 4.6076,
#    'largest_free_sphere_diameter': 3.59111,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.6076,
#    'ASA_m2_per_g': 775.121,
#    'POAV_cm3_per_g': 0.194591,
#    'POAV_fraction': 0.31854,
#    'Density_g_cm3': 1.63697},
#   {'id': 370,
#    'mof': 'ELILER_clean',
#    'md5': '24f47e65b0de4fd3c8f0453923375334',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 4.6076,
#    'Df': 3.59111,
#    'Dif': 4.6076,
#    'largest_included_sphere_diameter': 4.6076,
#    'largest_free_sphere_diameter': 3.59111,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.6076,
#    'ASA_m2_per_g': 724.172,
#    'POAV_cm3_per_g': 0.190938,
#    'POAV_fraction': 0.31256,
#    'Density_g_cm3': 1.63697},
#   {'id': 371,
#    'mof': 'ELILER_clean',
#    'md5': '24f47e65b0de4fd3c8f0453923375334',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 4.6076,
#    'Df': 3.59111,
#    'Dif': 4.6076,
#    'largest_included_sphere_diameter': 4.6076,
#    'largest_free_sphere_diameter': 3.59111,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.6076,
#    'ASA_m2_per_g': 654.218,
#    'POAV_cm3_per_g': 0.186277,
#    'POAV_fraction': 0.30493,
#    'Density_g_cm3': 1.63697},
#   {'id': 372,
#    'mof': 'EXIBUI_clean',
#    'md5': '912a0bd0e64ffa605348c360f16175e0',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 4.20713,
#    'Df': 2.9118,
#    'Dif': 4.1996,
#    'largest_included_sphere_diameter': 4.20713,
#    'largest_free_sphere_diameter': 2.9118,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.1996,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 1.86397},
#   {'id': 373,
#    'mof': 'EXIBUI_clean',
#    'md5': '912a0bd0e64ffa605348c360f16175e0',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 4.20713,
#    'Df': 2.9118,
#    'Dif': 4.1996,
#    'largest_included_sphere_diameter': 4.20713,
#    'largest_free_sphere_diameter': 2.9118,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.1996,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 1.86397},
#   {'id': 374,
#    'mof': 'EXIBUI_clean',
#    'md5': '912a0bd0e64ffa605348c360f16175e0',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 4.20713,
#    'Df': 2.9118,
#    'Dif': 4.1996,
#    'largest_included_sphere_diameter': 4.20713,
#    'largest_free_sphere_diameter': 2.9118,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.1996,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 1.86397},
#   {'id': 375,
#    'mof': 'GADFAV_clean',
#    'md5': '30d7005e525010e1056ae50572327df1',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 5.82985,
#    'Df': 4.65879,
#    'Dif': 5.82985,
#    'largest_included_sphere_diameter': 5.82985,
#    'largest_free_sphere_diameter': 4.65879,
#    'largest_included_sphere_diameter_along_free_sphere_path': 5.82985,
#    'ASA_m2_per_g': 571.126,
#    'POAV_cm3_per_g': 0.164173,
#    'POAV_fraction': 0.29468,
#    'Density_g_cm3': 1.79494},
#   {'id': 376,
#    'mof': 'GADFAV_clean',
#    'md5': '30d7005e525010e1056ae50572327df1',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 5.82985,
#    'Df': 4.65879,
#    'Dif': 5.82985,
#    'largest_included_sphere_diameter': 5.82985,
#    'largest_free_sphere_diameter': 4.65879,
#    'largest_included_sphere_diameter_along_free_sphere_path': 5.82985,
#    'ASA_m2_per_g': 538.549,
#    'POAV_cm3_per_g': 0.16137,
#    'POAV_fraction': 0.28965,
#    'Density_g_cm3': 1.79494},
#   {'id': 377,
#    'mof': 'GADFAV_clean',
#    'md5': '30d7005e525010e1056ae50572327df1',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 5.82985,
#    'Df': 4.65879,
#    'Dif': 5.82985,
#    'largest_included_sphere_diameter': 5.82985,
#    'largest_free_sphere_diameter': 4.65879,
#    'largest_included_sphere_diameter_along_free_sphere_path': 5.82985,
#    'ASA_m2_per_g': 492.34,
#    'POAV_cm3_per_g': 0.157287,
#    'POAV_fraction': 0.28232,
#    'Density_g_cm3': 1.79494},
#   {'id': 378,
#    'mof': 'GAJYUN_clean',
#    'md5': '51c86bd205edc3454842944b88b45fc7',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 4.61109,
#    'Df': 3.98142,
#    'Dif': 4.60119,
#    'largest_included_sphere_diameter': 4.61109,
#    'largest_free_sphere_diameter': 3.98142,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.60119,
#    'ASA_m2_per_g': 733.097,
#    'POAV_cm3_per_g': 0.179186,
#    'POAV_fraction': 0.27437,
#    'Density_g_cm3': 1.5312},
#   {'id': 379,
# ...
#    'ASA_m2_per_g': 5409.81,
#    'POAV_cm3_per_g': 2.51861,
#    'POAV_fraction': 0.82665,
#    'Density_g_cm3': 0.328217},
#   {'id': 538,
#    'mof': 'qmof-3beea42',
#    'md5': 'd151c224aed78554fad428c25f1b3124',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 6.97169,
#    'Df': 6.44739,
#    'Dif': 6.97169,
#    'largest_included_sphere_diameter': 6.97169,
#    'largest_free_sphere_diameter': 6.44739,
#    'largest_included_sphere_diameter_along_free_sphere_path': 6.97169,
#    'ASA_m2_per_g': 2908.05,
#    'POAV_cm3_per_g': 0.752406,
#    'POAV_fraction': 0.54743,
#    'Density_g_cm3': 0.727572},
#   {'id': 539,
#    'mof': 'qmof-3beea42',
#    'md5': 'd151c224aed78554fad428c25f1b3124',
#    'probe': 'H2',
#    'probe_radius': 1.48,
#    'scale': 1.0,
#    'block_radius': 1.48,
#    'Di': 6.97169,
#    'Df': 6.44739,
#    'Dif': 6.97169,
#    'largest_included_sphere_diameter': 6.97169,
#    'largest_free_sphere_diameter': 6.44739,
#    'largest_included_sphere_diameter_along_free_sphere_path': 6.97169,
#    'ASA_m2_per_g': 2993.27,
#    'POAV_cm3_per_g': 0.755691,
#    'POAV_fraction': 0.54982,
#    'Density_g_cm3': 0.727572},
#   {'id': 540,
#    'mof': 'qmof-3beea42',
#    'md5': 'd151c224aed78554fad428c25f1b3124',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 6.97169,
#    'Df': 6.44739,
#    'Dif': 6.97169,
#    'largest_included_sphere_diameter': 6.97169,
#    'largest_free_sphere_diameter': 6.44739,
#    'largest_included_sphere_diameter_along_free_sphere_path': 6.97169,
#    'ASA_m2_per_g': 2812.36,
#    'POAV_cm3_per_g': 0.739404,
#    'POAV_fraction': 0.53797,
#    'Density_g_cm3': 0.727572},
#   {'id': 541,
#    'mof': 'qmof-3beea42',
#    'md5': 'd151c224aed78554fad428c25f1b3124',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 6.97169,
#    'Df': 6.44739,
#    'Dif': 6.97169,
#    'largest_included_sphere_diameter': 6.97169,
#    'largest_free_sphere_diameter': 6.44739,
#    'largest_included_sphere_diameter_along_free_sphere_path': 6.97169,
#    'ASA_m2_per_g': 2680.68,
#    'POAV_cm3_per_g': 0.723282,
#    'POAV_fraction': 0.52624,
#    'Density_g_cm3': 0.727572},
#   {'id': 542,
#    'mof': 'qmof-798e431',
#    'md5': '853c87c73a38c205d09c91658fda10f8',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 15.99888,
#    'Df': 12.91569,
#    'Dif': 15.99356,
#    'largest_included_sphere_diameter': 15.99888,
#    'largest_free_sphere_diameter': 12.91569,
#    'largest_included_sphere_diameter_along_free_sphere_path': 15.99356,
#    'ASA_m2_per_g': 5453.05,
#    'POAV_cm3_per_g': 2.7079,
#    'POAV_fraction': 0.83764,
#    'Density_g_cm3': 0.309333},
#   {'id': 543,
#    'mof': 'qmof-798e431',
#    'md5': '853c87c73a38c205d09c91658fda10f8',
#    'probe': 'H2',
#    'probe_radius': 1.48,
#    'scale': 1.0,
#    'block_radius': 1.48,
#    'Di': 15.99888,
#    'Df': 12.91569,
#    'Dif': 15.99356,
#    'largest_included_sphere_diameter': 15.99888,
#    'largest_free_sphere_diameter': 12.91569,
#    'largest_included_sphere_diameter_along_free_sphere_path': 15.99356,
#    'ASA_m2_per_g': 5454.04,
#    'POAV_cm3_per_g': 2.70945,
#    'POAV_fraction': 0.83812,
#    'Density_g_cm3': 0.309333},
#   {'id': 544,
#    'mof': 'qmof-798e431',
#    'md5': '853c87c73a38c205d09c91658fda10f8',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 15.99888,
#    'Df': 12.91569,
#    'Dif': 15.99356,
#    'largest_included_sphere_diameter': 15.99888,
#    'largest_free_sphere_diameter': 12.91569,
#    'largest_included_sphere_diameter_along_free_sphere_path': 15.99356,
#    'ASA_m2_per_g': 5454.6,
#    'POAV_cm3_per_g': 2.70566,
#    'POAV_fraction': 0.83695,
#    'Density_g_cm3': 0.309333},
#   {'id': 545,
#    'mof': 'qmof-798e431',
#    'md5': '853c87c73a38c205d09c91658fda10f8',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 15.99888,
#    'Df': 12.91569,
#    'Dif': 15.99356,
#    'largest_included_sphere_diameter': 15.99888,
#    'largest_free_sphere_diameter': 12.91569,
#    'largest_included_sphere_diameter_along_free_sphere_path': 15.99356,
#    'ASA_m2_per_g': 5467.19,
#    'POAV_cm3_per_g': 2.70211,
#    'POAV_fraction': 0.83585,
#    'Density_g_cm3': 0.309333},
#   {'id': 546,
#    'mof': 'qmof-7c567fa',
#    'md5': '650007ea35848e188b1dc4c34efe99ab',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 14.01148,
#    'Df': 10.35684,
#    'Dif': 14.01148,
#    'largest_included_sphere_diameter': 14.01148,
#    'largest_free_sphere_diameter': 10.35684,
#    'largest_included_sphere_diameter_along_free_sphere_path': 14.01148,
#    'ASA_m2_per_g': 5696.72,
#    'POAV_cm3_per_g': 2.38297,
#    'POAV_fraction': 0.816,
#    'Density_g_cm3': 0.34243},
#   {'id': 547,
#    'mof': 'qmof-7c567fa',
#    'md5': '650007ea35848e188b1dc4c34efe99ab',
#    'probe': 'H2',
#    'probe_radius': 1.48,
#    'scale': 1.0,
#    'block_radius': 1.48,
#    'Di': 14.01148,
#    'Df': 10.35684,
#    'Dif': 14.01148,
#    'largest_included_sphere_diameter': 14.01148,
#    'largest_free_sphere_diameter': 10.35684,
#    'largest_included_sphere_diameter_along_free_sphere_path': 14.01148,
#    'ASA_m2_per_g': 5696.81,
#    'POAV_cm3_per_g': 2.38533,
#    'POAV_fraction': 0.81681,
#    'Density_g_cm3': 0.34243},
#   {'id': 548,
#    'mof': 'qmof-7c567fa',
#    'md5': '650007ea35848e188b1dc4c34efe99ab',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 14.01148,
#    'Df': 10.35684,
#    'Dif': 14.01148,
#    'largest_included_sphere_diameter': 14.01148,
#    'largest_free_sphere_diameter': 10.35684,
#    'largest_included_sphere_diameter_along_free_sphere_path': 14.01148,
#    'ASA_m2_per_g': 5709.04,
#    'POAV_cm3_per_g': 2.38005,
#    'POAV_fraction': 0.815,
#    'Density_g_cm3': 0.34243},
#   {'id': 549,
#    'mof': 'qmof-7c567fa',
#    'md5': '650007ea35848e188b1dc4c34efe99ab',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 14.01148,
#    'Df': 10.35684,
#    'Dif': 14.01148,
#    'largest_included_sphere_diameter': 14.01148,
#    'largest_free_sphere_diameter': 10.35684,
#    'largest_included_sphere_diameter_along_free_sphere_path': 14.01148,
#    'ASA_m2_per_g': 5698.86,
#    'POAV_cm3_per_g': 2.37342,
#    'POAV_fraction': 0.81273,
#    'Density_g_cm3': 0.34243},
#   {'id': 550,
#    'mof': 'qmof-97d5d0e',
#    'md5': 'c1e3adaea2ae0e27eb3fe8cdd2b39ac6',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 17.20209,
#    'Df': 12.59909,
#    'Dif': 17.20209,
#    'largest_included_sphere_diameter': 17.20209,
#    'largest_free_sphere_diameter': 12.59909,
#    'largest_included_sphere_diameter_along_free_sphere_path': 17.20209,
#    'ASA_m2_per_g': 5995.12,
#    'POAV_cm3_per_g': 3.60968,
#    'POAV_fraction': 0.86975,
#    'Density_g_cm3': 0.240949},
#   {'id': 551,
#    'mof': 'qmof-97d5d0e',
#    'md5': 'c1e3adaea2ae0e27eb3fe8cdd2b39ac6',
#    'probe': 'H2',
#    'probe_radius': 1.48,
#    'scale': 1.0,
#    'block_radius': 1.48,
#    'Di': 17.20209,
#    'Df': 12.59909,
#    'Dif': 17.20209,
#    'largest_included_sphere_diameter': 17.20209,
#    'largest_free_sphere_diameter': 12.59909,
#    'largest_included_sphere_diameter_along_free_sphere_path': 17.20209,
#    'ASA_m2_per_g': 5976.36,
#    'POAV_cm3_per_g': 3.61109,
#    'POAV_fraction': 0.87009,
#    'Density_g_cm3': 0.240949},
#   {'id': 552,
#    'mof': 'qmof-97d5d0e',
#    'md5': 'c1e3adaea2ae0e27eb3fe8cdd2b39ac6',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 17.20209,
#    'Df': 12.59909,
#    'Dif': 17.20209,
#    'largest_included_sphere_diameter': 17.20209,
#    'largest_free_sphere_diameter': 12.59909,
#    'largest_included_sphere_diameter_along_free_sphere_path': 17.20209,
#    'ASA_m2_per_g': 6021.9,
#    'POAV_cm3_per_g': 3.60765,
#    'POAV_fraction': 0.86926,
#    'Density_g_cm3': 0.240949},
#   {'id': 553,
#    'mof': 'qmof-97d5d0e',
#    'md5': 'c1e3adaea2ae0e27eb3fe8cdd2b39ac6',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 17.20209,
#    'Df': 12.59909,
#    'Dif': 17.20209,
#    'largest_included_sphere_diameter': 17.20209,
#    'largest_free_sphere_diameter': 12.59909,
#    'largest_included_sphere_diameter_along_free_sphere_path': 17.20209,
#    'ASA_m2_per_g': 6068.73,
#    'POAV_cm3_per_g': 3.60578,
#    'POAV_fraction': 0.86881,
#    'Density_g_cm3': 0.240949},
#   {'id': 554,
#    'mof': 'qmof-9fd01d7',
#    'md5': 'a07d8cb4f99171f7ce36244c3f8669cd',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 18.35928,
#    'Df': 14.54846,
#    'Dif': 18.35928,
#    'largest_included_sphere_diameter': 18.35928,
#    'largest_free_sphere_diameter': 14.54846,
#    'largest_included_sphere_diameter_along_free_sphere_path': 18.35928,
#    'ASA_m2_per_g': 5279.46,
#    'POAV_cm3_per_g': 2.53265,
#    'POAV_fraction': 0.82216,
#    'Density_g_cm3': 0.324624},
#   {'id': 555,
#    'mof': 'qmof-9fd01d7',
#    'md5': 'a07d8cb4f99171f7ce36244c3f8669cd',
#    'probe': 'H2',
#    'probe_radius': 1.48,
#    'scale': 1.0,
#    'block_radius': 1.48,
#    'Di': 18.35928,
#    'Df': 14.54846,
#    'Dif': 18.35928,
#    'largest_included_sphere_diameter': 18.35928,
#    'largest_free_sphere_diameter': 14.54846,
#    'largest_included_sphere_diameter_along_free_sphere_path': 18.35928,
#    'ASA_m2_per_g': 5293.77,
#    'POAV_cm3_per_g': 2.53441,
#    'POAV_fraction': 0.82273,
#    'Density_g_cm3': 0.324624},
#   {'id': 556,
#    'mof': 'qmof-9fd01d7',
#    'md5': 'a07d8cb4f99171f7ce36244c3f8669cd',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 18.35928,
#    'Df': 14.54846,
#    'Dif': 18.35928,
#    'largest_included_sphere_diameter': 18.35928,
#    'largest_free_sphere_diameter': 14.54846,
#    'largest_included_sphere_diameter_along_free_sphere_path': 18.35928,
#    'ASA_m2_per_g': 5275.69,
#    'POAV_cm3_per_g': 2.53037,
#    'POAV_fraction': 0.82142,
#    'Density_g_cm3': 0.324624},
#   {'id': 557,
#    'mof': 'qmof-9fd01d7',
#    'md5': 'a07d8cb4f99171f7ce36244c3f8669cd',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 18.35928,
#    'Df': 14.54846,
#    'Dif': 18.35928,
#    'largest_included_sphere_diameter': 18.35928,
#    'largest_free_sphere_diameter': 14.54846,
#    'largest_included_sphere_diameter_along_free_sphere_path': 18.35928,
#    'ASA_m2_per_g': 5273.94,
#    'POAV_cm3_per_g': 2.52649,
#    'POAV_fraction': 0.82016,
#    'Density_g_cm3': 0.324624},
#   {'id': 558,
#    'mof': 'qmof-b4192d1',
#    'md5': 'e765fd21c2e55927a13b44ad71f14688',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 7.50948,
#    'Df': 4.74764,
#    'Dif': 7.50725,
#    'largest_included_sphere_diameter': 7.50948,
#    'largest_free_sphere_diameter': 4.74764,
#    'largest_included_sphere_diameter_along_free_sphere_path': 7.50725,
#    'ASA_m2_per_g': 2832.45,
#    'POAV_cm3_per_g': 0.685455,
#    'POAV_fraction': 0.54647,
#    'Density_g_cm3': 0.797236},
#   {'id': 559,
#    'mof': 'qmof-b4192d1',
#    'md5': 'e765fd21c2e55927a13b44ad71f14688',
#    'probe': 'H2',
#    'probe_radius': 1.48,
#    'scale': 1.0,
#    'block_radius': 1.48,
#    'Di': 7.50948,
#    'Df': 4.74764,
#    'Dif': 7.50725,
#    'largest_included_sphere_diameter': 7.50948,
#    'largest_free_sphere_diameter': 4.74764,
#    'largest_included_sphere_diameter_along_free_sphere_path': 7.50725,
#    'ASA_m2_per_g': 2906.78,
#    'POAV_cm3_per_g': 0.687412,
#    'POAV_fraction': 0.54803,
#    'Density_g_cm3': 0.797236},
#   {'id': 560,
#    'mof': 'qmof-b4192d1',
#    'md5': 'e765fd21c2e55927a13b44ad71f14688',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 7.50948,
#    'Df': 4.74764,
#    'Dif': 7.50725,
#    'largest_included_sphere_diameter': 7.50948,
#    'largest_free_sphere_diameter': 4.74764,
#    'largest_included_sphere_diameter_along_free_sphere_path': 7.50725,
#    'ASA_m2_per_g': 2745.15,
#    'POAV_cm3_per_g': 0.681956,
#    'POAV_fraction': 0.54368,
#    'Density_g_cm3': 0.797236},
#   {'id': 561,
#    'mof': 'qmof-b4192d1',
#    'md5': 'e765fd21c2e55927a13b44ad71f14688',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 7.50948,
#    'Df': 4.74764,
#    'Dif': 7.50725,
#    'largest_included_sphere_diameter': 7.50948,
#    'largest_free_sphere_diameter': 4.74764,
#    'largest_included_sphere_diameter_along_free_sphere_path': 7.50725,
#    'ASA_m2_per_g': 2607.43,
#    'POAV_cm3_per_g': 0.676775,
#    'POAV_fraction': 0.53955,
#    'Density_g_cm3': 0.797236},
#   {'id': 562,
#    'mof': 'qmof-cb9ea13',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 6.68675,
#    'Df': 5.9701,
#    'Dif': 6.49067,
#    'largest_included_sphere_diameter': 6.68675,
#    'largest_free_sphere_diameter': 5.9701,
#    'largest_included_sphere_diameter_along_free_sphere_path': 6.49067,
#    'ASA_m2_per_g': 2393.65,
#    'POAV_cm3_per_g': 0.653146,
#    'POAV_fraction': 0.52419,
#    'Density_g_cm3': 0.802561},
#   {'id': 563,
#    'mof': 'qmof-cb9ea13',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'probe': 'H2',
#    'probe_radius': 1.48,
#    'scale': 1.0,
#    'block_radius': 1.48,
#    'Di': 6.68675,
#    'Df': 5.9701,
#    'Dif': 6.49067,
#    'largest_included_sphere_diameter': 6.68675,
#    'largest_free_sphere_diameter': 5.9701,
#    'largest_included_sphere_diameter_along_free_sphere_path': 6.49067,
#    'ASA_m2_per_g': 2425.71,
#    'POAV_cm3_per_g': 0.656311,
#    'POAV_fraction': 0.52673,
#    'Density_g_cm3': 0.802561},
#   {'id': 564,
#    'mof': 'qmof-cb9ea13',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 6.68675,
#    'Df': 5.9701,
#    'Dif': 6.49067,
#    'largest_included_sphere_diameter': 6.68675,
#    'largest_free_sphere_diameter': 5.9701,
#    'largest_included_sphere_diameter_along_free_sphere_path': 6.49067,
#    'ASA_m2_per_g': 2335.4,
#    'POAV_cm3_per_g': 0.649894,
#    'POAV_fraction': 0.52158,
#    'Density_g_cm3': 0.802561},
#   {'id': 565,
#    'mof': 'qmof-cb9ea13',
#    'md5': 'fe0d68fc6501829858ecb3504b2ca35e',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 6.68675,
#    'Df': 5.9701,
#    'Dif': 6.49067,
#    'largest_included_sphere_diameter': 6.68675,
#    'largest_free_sphere_diameter': 5.9701,
#    'largest_included_sphere_diameter_along_free_sphere_path': 6.49067,
#    'ASA_m2_per_g': 2264.42,
#    'POAV_cm3_per_g': 0.643988,
#    'POAV_fraction': 0.51684,
#    'Density_g_cm3': 0.802561},
#   {'id': 566,
#    'mof': 'str_m4_o1_o4_acs_sym.68',
#    'md5': '1c9a5d68fac18068899ecdbb6a47507f',
#    'probe': 'CO2',
#    'probe_radius': 1.525,
#    'scale': 1.0,
#    'block_radius': 1.525,
#    'Di': 5.05869,
#    'Df': 3.10574,
#    'Dif': 4.5612,
#    'largest_included_sphere_diameter': 5.05869,
#    'largest_free_sphere_diameter': 3.10574,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.5612,
#    'ASA_m2_per_g': 128.661,
#    'POAV_cm3_per_g': 0.0388237,
#    'POAV_fraction': 0.05562,
#    'Density_g_cm3': 1.43263},
#   {'id': 567,
#    'mof': 'str_m4_o1_o4_acs_sym.68',
#    'md5': '1c9a5d68fac18068899ecdbb6a47507f',
#    'probe': 'H2O',
#    'probe_radius': 1.577,
#    'scale': 1.0,
#    'block_radius': 1.577,
#    'Di': 5.05869,
#    'Df': 3.10574,
#    'Dif': 4.5612,
#    'largest_included_sphere_diameter': 5.05869,
#    'largest_free_sphere_diameter': 3.10574,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.5612,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 1.43263},
#   {'id': 568,
#    'mof': 'str_m4_o1_o4_acs_sym.68',
#    'md5': '1c9a5d68fac18068899ecdbb6a47507f',
#    'probe': 'N2',
#    'probe_radius': 1.655,
#    'scale': 1.0,
#    'block_radius': 1.655,
#    'Di': 5.05869,
#    'Df': 3.10574,
#    'Dif': 4.5612,
#    'largest_included_sphere_diameter': 5.05869,
#    'largest_free_sphere_diameter': 3.10574,
#    'largest_included_sphere_diameter_along_free_sphere_path': 4.5612,
#    'ASA_m2_per_g': 0.0,
#    'POAV_cm3_per_g': 0.0,
#    'POAV_fraction': 0.0,
#    'Density_g_cm3': 1.43263}]}
